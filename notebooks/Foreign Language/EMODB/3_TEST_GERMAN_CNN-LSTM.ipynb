# %%
# Reseteamos todas las variables del entorno
# %reset
# IMPORT LIBRARIES

# Processing
import librosa
import librosa.display
import numpy as np
import random
from tqdm import tqdm

# Visualization
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import IPython.display as ipd

# Files
import os
import joblib
import pickle

# Machine Learning
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.metrics import confusion_matrix
import keras
from keras.utils import np_utils
from tensorflow.keras.utils import to_categorical
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras.models import Sequential, Model, model_from_json
from keras.layers import Dense, Embedding, LSTM
from keras.layers import Input, Flatten, Dropout, Activation, BatchNormalization
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Reshape
import tensorflow as tf

# ####### TEST ####### 
# Scipy
from scipy import signal
from scipy.io import wavfile
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %% [markdown]
# # **CONFIGURACION DEL ENTORNO**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys  
GPATH = '/content/drive/My Drive/Master/Asignaturas/2 Cuatrimestre/Proyecto/Code/'

if GPATH + '/SpeechEmotionRecognition' in sys.path:
  sys.path.remove(GPATH + '/SpeechEmotionRecognition')

sys.path.insert(0, GPATH + '/SpeechEmotionRecognition')

sys.path
# Out:
# ['/content/drive/My Drive/Master/Asignaturas/2 Cuatrimestre/Proyecto/Code//SpeechEmotionRecognition',
#  '',
#  '/content',
#  '/env/python',
#  '/usr/lib/python37.zip',
#  '/usr/lib/python3.7',
#  '/usr/lib/python3.7/lib-dynload',
#  '/usr/local/lib/python3.7/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.7/dist-packages/IPython/extensions',
#  '/root/.ipython']

# %%
FEATURES_PATH = GPATH + 'SpeechEmotionRecognition/data/processed/features/'
FIGURES_PATH = GPATH + 'SpeechEmotionRecognition/reports/figures/'
# Datasets
SAVEE_PATH = GPATH + 'data/SAVEE/'
TESS_PATH = GPATH + 'data/TESS/'
RAVDESS_PATH = GPATH + 'data/RAVDESS/'
EMODB_PATH = GPATH + 'data/EMODB/'

# Espectogramas
SPECT_IMG = GPATH + 'data/spectrograms/'
SPECTOGRAM_MODEL = SPECT_IMG + 'mfcc_savee_tess/test_german'

# Maps
EMOTION_MAP = {4:'neutral', 2:'happy', 3:'sad', 0:'angry', 1:'disgust'}
reduced_values = ['angry', 'disgust', 'happy', 'sad', 'neutral']

# %% [markdown]
# ## **1. DATOS**

# %%
# Leemos EMO-DB
EMOTION_EMODB_MAP = {'F':'happy', 'T':'sad', 'W':'angry','E':'disgust', 'N':'neutral'}
emotion=[]
path = []

for filename in os.listdir(EMODB_PATH):
  str_path = EMODB_PATH +  '/' + str(filename)
  emo_capital = filename[5]
  if emo_capital in EMOTION_EMODB_MAP:
    emotion.append(EMOTION_EMODB_MAP[emo_capital])
    path.append(str_path)
  
EMODDB_df = pd.DataFrame(columns=['emotion', 'path'])
EMODDB_df['emotion'] = emotion
EMODDB_df['path'] = path

class_distribution = EMODDB_df['emotion'].value_counts()
print( class_distribution )
# Out:
# angry      127
# neutral     79
# happy       71
# sad         62
# disgust     46
# Name: emotion, dtype: int64

# %%
print( class_distribution )
# Out:
# angry      127
# neutral     79
# happy       71
# sad         62
# disgust     46
# Name: emotion, dtype: int64

# %%
# from src.SpeechDataProcess import SpeechDataProcess
# data = SpeechDataProcess('TESS', TESS_PATH)
# TESS_df = data.read()
# data = SpeechDataProcess('SAVEE', SAVEE_PATH)
# SAVEE_df = data.read()

# %%
emotion=[]
path = []
reduced_values = ['a', 'd', 'h', 'sa', 'n']

for dir in os.listdir(SAVEE_PATH):
  path_dir = os.listdir(SAVEE_PATH + dir) # todos los archivos de audios asociados a un directorio
  for filename in path_dir:
    str_path = SAVEE_PATH + dir + '/' + str(filename)
    label = filename[0]
    if filename[1].isalpha() : label = filename[0] + filename[1] 
    # Solo los valores reducidos
    if label in reduced_values:
      path.append(str_path)
      if(label=='a'):
          emotion.append("angry")
      elif(label=='h'):
          emotion.append("happy")
      elif(label=='f'):
          emotion.append("fear")
      elif(label=='d'):
          emotion.append("disgust")
      elif(label=='n'):
          emotion.append('neutral')
      elif(label=='sa'):
          emotion.append("sad")
      elif(label=='su'):
          emotion.append("surprise")


SAVEE_df = pd.DataFrame(columns=['emotion', 'path'])
SAVEE_df['emotion'] = emotion
SAVEE_df['path'] = path

SAVEE_df['emotion'].unique()
print( SAVEE_df['emotion'].value_counts() )
# Out:
# neutral    120
# sad         60
# angry       60
# happy       60
# disgust     60
# Name: emotion, dtype: int64

# %%
# Leemos TESS

emotion=[]
path = []
reduced_values = ['angry', 'disgust', 'happy', 'sad', 'neutral']
for dir in os.listdir(TESS_PATH):
  path_dir = os.listdir(TESS_PATH + dir) # todos los archivos de audios asociados a un directorio
  label = dir.split('_')[1]
  for filename in path_dir:
    str_path = TESS_PATH + dir + '/' + str(filename)

    # Solo los valores reducidos
    if label.lower() in reduced_values:
      path.append(str_path)
      emotion.append(label.lower())


TESS_df = pd.DataFrame(columns=['emotion', 'path'])
TESS_df['emotion'] = emotion
TESS_df['path'] = path

print( "Size of the dataset: {} \n".format(len(TESS_df)) )
print( TESS_df['emotion'].value_counts() )
# TESS_df.sample(5)
# Out:
# Size of the dataset: 2000
#
# sad        400
# angry      400
# neutral    400
# happy      400
# disgust    400
# Name: emotion, dtype: int64

# %%
if len(TESS_df.emotion.unique()) == len(SAVEE_df.emotion.unique()) and len(TESS_df.emotion.unique()) == len(EMODDB_df.emotion.unique()):
  print("Todas las dimensiones son correctas")
# Out:
# Todas las dimensiones son correctas

# %% [markdown]
# ### **1.2 EXTRACCION DE ESPECTROGRAMAS**

# %%
from src.MFCC import MFCC

# %%
features_spectMFCC_SAVEE = MFCC(df_data = SAVEE_df, dataset_name = "SAVEE")
features_spectMFCC_TESS = MFCC(df_data = TESS_df, dataset_name = "TESS")

features_spectMFCC_EMODB = MFCC(df_data = EMODDB_df, dataset_name = "EMODB")
# list_images, labels = featuresMFCC_SAVEE.load_images(IMG_MFCC, (40,40))

# %%
# # Genero los espectrogramas
# features_spectMFCC_SAVEE.generate_spectrograms(SPECT_IMG)
# features_spectMFCC_TESS.generate_spectrograms(SPECT_IMG)

# # Genero los espectogramas de test
# features_spectMFCC_EMODB.generate_spectrograms(SPECT_IMG + 'test_emodb/')

# %%
list_images_savee_tess, labels = features_spectMFCC_TESS.load_spectograms_dataset(SPECTOGRAM_MODEL, (30,40))
# Out:
# Leídas 460 espectogramas pertenecientes a angry
# Leídas 460 espectogramas pertenecientes a disgust
# Leídas 460 espectogramas pertenecientes a happy
# Leídas 524 espectogramas pertenecientes a neutral
# Leídas 460 espectogramas pertenecientes a sad

# %%
array_images_savee_tess = np.array(list_images_savee_tess)
print("{} imagenes con dimension {}".format(array_images_savee_tess.shape[0], array_images_savee_tess.shape[1:]))
# Out:
# 2364 imagenes con dimension (40, 30, 3)

# %%
list_images_emodb, labels_emodb = features_spectMFCC_EMODB.load_spectograms_dataset(SPECT_IMG + 'test_emodb/', (30,40))
array_images_emodb= np.array(list_images_emodb)
# Out:
# Leídas 400 espectogramas pertenecientes a disgust
# Leídas 400 espectogramas pertenecientes a sad
# Leídas 400 espectogramas pertenecientes a happy
# Leídas 400 espectogramas pertenecientes a neutral
# Leídas 400 espectogramas pertenecientes a angry

# %% [markdown]
# ## **2. DEFINICION DEL MODELO**

# %%
def get_model_LSTM_CNN(shape, classes):
  model = Sequential()

  # 1 Capa CNN 2D
  model.add(Conv2D(64, (3, 3), padding = 'same', input_shape = shape, activation = 'relu')) # (128, 128, 3)
  model.add(MaxPooling2D(pool_size = (2, 2)))

  # 2 Capa CNN 2D
  model.add(Conv2D(64, (3, 3), padding = 'same', activation = 'relu'))
  model.add(MaxPooling2D(pool_size = (2, 2)))

  # 3 Capa CNN 2D
  model.add(Conv2D(64, (3, 3), padding = 'same', activation = 'relu'))
  model.add(MaxPooling2D(pool_size = (2, 2)))

  # Capa Flatten
  model.add(Flatten())
  model.add(Dropout(rate = 0.5))

  # Capas LSTM 1D
  model.add(Reshape((1, 960))) 
  model.add(LSTM(units = 50, return_sequences = True, dropout = 0.5))
  model.add(LSTM(units = 20, return_sequences = False, dropout = 0.5))

  model.add(Dense(classes, activation = 'softmax'))

  return model


def plot_loss_acc(history):
  # Mostramos la grafica loss 
  fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
  ax1.plot(history.history['loss'])
  ax1.plot(history.history['val_loss'])
  ax1.set_title('Loss')
  ax1.set(xlabel='epoch', ylabel='loss')
  ax1.legend(['train', 'test'], loc='upper right')

  # Mostramos la grafica accuracy
  ax2.plot(history.history['accuracy'])
  ax2.plot(history.history['val_accuracy'])
  ax2.set_title('Validation')
  ax2.set(xlabel='epoch', ylabel='acc')

  ax2.legend(['train', 'test'], loc='lower right')


def processData(data, labels, test_size = 0.25):
  X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=test_size, shuffle=True, random_state=42)

  # one hot encoding 
  lb = LabelEncoder()
  y_train = np_utils.to_categorical(lb.fit_transform(y_train))
  y_test = np_utils.to_categorical(lb.fit_transform(y_test))

  # Normalization as per the standard NN process
  mean = np.mean(X_train, axis=0)
  std = np.std(X_train, axis=0)

  X_train = (X_train - mean)/std
  X_test = (X_test - mean)/std

  return X_train, X_test, y_train, y_test

# %% [markdown]
# #### **2.1 ENTRENAMIENTO**

# %%
X_train, X_test, y_train, y_test = processData(array_images_savee_tess, labels, 0.3)

# %%
print("Entrenamiento: Datos con dimension {}, y clases con {}".format(X_train.shape, y_train.shape))
print("Test: Datos con dimension {}, y clases con {}".format(X_test.shape, y_test.shape))
# Out:
# Entrenamiento: Datos con dimension (1654, 40, 30, 3), y clases con (1654, 5)
# Test: Datos con dimension (710, 40, 30, 3), y clases con (710, 5)

# %%
model = get_model_LSTM_CNN(X_train.shape[1:], y_train.shape[1])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 40, 30, 64)        1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 20, 15, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 20, 15, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 7, 64)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 10, 7, 64)         36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 3, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 960)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 960)               0
# _________________________________________________________________
# reshape (Reshape)            (None, 1, 960)            0
# _________________________________________________________________
# lstm (LSTM)                  (None, 1, 50)             202200
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 20)                5680
# _________________________________________________________________
# dense (Dense)                (None, 5)                 105
# =================================================================
# Total params: 283,633
# Trainable params: 283,633
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(X_train, y_train, 
                      batch_size=32, 
                      epochs=100, 
                      validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 52/52 [==============================] - 31s 160ms/step - loss: 1.5955 - accuracy: 0.2512 - val_loss: 1.5310 - val_accuracy: 0.3000
# Epoch 2/100
# 52/52 [==============================] - 7s 130ms/step - loss: 1.5235 - accuracy: 0.3530 - val_loss: 1.4565 - val_accuracy: 0.3634
# Epoch 3/100
# 52/52 [==============================] - 7s 132ms/step - loss: 1.4682 - accuracy: 0.3764 - val_loss: 1.3270 - val_accuracy: 0.4282
# Epoch 4/100
# 52/52 [==============================] - 7s 132ms/step - loss: 1.3208 - accuracy: 0.4820 - val_loss: 1.0452 - val_accuracy: 0.6141
# Epoch 5/100
# 52/52 [==============================] - 7s 132ms/step - loss: 1.1113 - accuracy: 0.5879 - val_loss: 0.7665 - val_accuracy: 0.7507
# Epoch 6/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.8657 - accuracy: 0.7076 - val_loss: 0.5782 - val_accuracy: 0.8183
# Epoch 7/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.7119 - accuracy: 0.7618 - val_loss: 0.5561 - val_accuracy: 0.8169
# Epoch 8/100
# 52/52 [==============================] - 7s 133ms/step - loss: 0.6631 - accuracy: 0.7643 - val_loss: 0.4736 - val_accuracy: 0.8465
# Epoch 9/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.5719 - accuracy: 0.8056 - val_loss: 0.4792 - val_accuracy: 0.8507
# Epoch 10/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.5167 - accuracy: 0.8156 - val_loss: 0.3791 - val_accuracy: 0.8648
# Epoch 11/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.4528 - accuracy: 0.8425 - val_loss: 0.3648 - val_accuracy: 0.8648
# Epoch 12/100
# 52/52 [==============================] - 7s 131ms/step - loss: 0.4242 - accuracy: 0.8545 - val_loss: 0.3567 - val_accuracy: 0.8704
# Epoch 13/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.4595 - accuracy: 0.8443 - val_loss: 0.3318 - val_accuracy: 0.8746
# Epoch 14/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.3750 - accuracy: 0.8670 - val_loss: 0.3239 - val_accuracy: 0.8915
# Epoch 15/100
# 52/52 [==============================] - 7s 144ms/step - loss: 0.3836 - accuracy: 0.8840 - val_loss: 0.3174 - val_accuracy: 0.8958
# Epoch 16/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.3038 - accuracy: 0.9026 - val_loss: 0.2926 - val_accuracy: 0.8986
# Epoch 17/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.3358 - accuracy: 0.8852 - val_loss: 0.2964 - val_accuracy: 0.8901
# Epoch 18/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.3557 - accuracy: 0.8736 - val_loss: 0.2852 - val_accuracy: 0.8901
# Epoch 19/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.3091 - accuracy: 0.8777 - val_loss: 0.2541 - val_accuracy: 0.9028
# Epoch 20/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.3144 - accuracy: 0.8880 - val_loss: 0.2806 - val_accuracy: 0.8958
# Epoch 21/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.3263 - accuracy: 0.8793 - val_loss: 0.3093 - val_accuracy: 0.8887
# Epoch 22/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.2812 - accuracy: 0.8981 - val_loss: 0.2432 - val_accuracy: 0.9085
# Epoch 23/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.2903 - accuracy: 0.8944 - val_loss: 0.2505 - val_accuracy: 0.9028
# Epoch 24/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.2539 - accuracy: 0.8967 - val_loss: 0.2242 - val_accuracy: 0.9155
# Epoch 25/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.2704 - accuracy: 0.8951 - val_loss: 0.2348 - val_accuracy: 0.9169
# Epoch 26/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.2551 - accuracy: 0.8971 - val_loss: 0.2254 - val_accuracy: 0.9099
# Epoch 27/100
# 52/52 [==============================] - 7s 131ms/step - loss: 0.2693 - accuracy: 0.8959 - val_loss: 0.2177 - val_accuracy: 0.9141
# Epoch 28/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.2266 - accuracy: 0.9142 - val_loss: 0.2169 - val_accuracy: 0.9169
# Epoch 29/100
# 52/52 [==============================] - 7s 131ms/step - loss: 0.2046 - accuracy: 0.9252 - val_loss: 0.2228 - val_accuracy: 0.9085
# Epoch 30/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.2359 - accuracy: 0.9082 - val_loss: 0.2155 - val_accuracy: 0.9141
# Epoch 31/100
# 52/52 [==============================] - 7s 131ms/step - loss: 0.2732 - accuracy: 0.8958 - val_loss: 0.2251 - val_accuracy: 0.9127
# Epoch 32/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.2323 - accuracy: 0.9119 - val_loss: 0.2102 - val_accuracy: 0.9169
# Epoch 33/100
# 52/52 [==============================] - 7s 133ms/step - loss: 0.2253 - accuracy: 0.9076 - val_loss: 0.2085 - val_accuracy: 0.9197
# Epoch 34/100
# 52/52 [==============================] - 7s 133ms/step - loss: 0.2067 - accuracy: 0.9193 - val_loss: 0.2194 - val_accuracy: 0.9169
# Epoch 35/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.1850 - accuracy: 0.9330 - val_loss: 0.2350 - val_accuracy: 0.9070
# Epoch 36/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.2049 - accuracy: 0.9281 - val_loss: 0.2213 - val_accuracy: 0.9197
# Epoch 37/100
# 52/52 [==============================] - 7s 131ms/step - loss: 0.2192 - accuracy: 0.9192 - val_loss: 0.2141 - val_accuracy: 0.9239
# Epoch 38/100
# 52/52 [==============================] - 7s 131ms/step - loss: 0.2165 - accuracy: 0.9192 - val_loss: 0.2022 - val_accuracy: 0.9211
# Epoch 39/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.1739 - accuracy: 0.9325 - val_loss: 0.2118 - val_accuracy: 0.9183
# Epoch 40/100
# 52/52 [==============================] - 7s 131ms/step - loss: 0.2094 - accuracy: 0.9258 - val_loss: 0.2150 - val_accuracy: 0.9183
# Epoch 41/100
# 52/52 [==============================] - 7s 131ms/step - loss: 0.2059 - accuracy: 0.9186 - val_loss: 0.2080 - val_accuracy: 0.9141
# Epoch 42/100
# 52/52 [==============================] - 7s 131ms/step - loss: 0.1673 - accuracy: 0.9480 - val_loss: 0.2189 - val_accuracy: 0.9155
# Epoch 43/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.2163 - accuracy: 0.9180 - val_loss: 0.2213 - val_accuracy: 0.9282
# Epoch 44/100
# 52/52 [==============================] - 7s 131ms/step - loss: 0.2265 - accuracy: 0.9090 - val_loss: 0.2018 - val_accuracy: 0.9155
# Epoch 45/100
# 52/52 [==============================] - 7s 131ms/step - loss: 0.1938 - accuracy: 0.9254 - val_loss: 0.2100 - val_accuracy: 0.9225
# Epoch 46/100
# 52/52 [==============================] - 7s 131ms/step - loss: 0.1821 - accuracy: 0.9317 - val_loss: 0.2016 - val_accuracy: 0.9239
# Epoch 47/100
# 52/52 [==============================] - 7s 131ms/step - loss: 0.1855 - accuracy: 0.9230 - val_loss: 0.2180 - val_accuracy: 0.9211
# Epoch 48/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.1973 - accuracy: 0.9339 - val_loss: 0.2043 - val_accuracy: 0.9254
# Epoch 49/100
# 52/52 [==============================] - 7s 131ms/step - loss: 0.1629 - accuracy: 0.9366 - val_loss: 0.2315 - val_accuracy: 0.9141
# Epoch 50/100
# 52/52 [==============================] - 7s 131ms/step - loss: 0.1777 - accuracy: 0.9379 - val_loss: 0.1964 - val_accuracy: 0.9197
# Epoch 51/100
# 52/52 [==============================] - 7s 131ms/step - loss: 0.1846 - accuracy: 0.9391 - val_loss: 0.2079 - val_accuracy: 0.9254
# Epoch 52/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.1598 - accuracy: 0.9367 - val_loss: 0.2154 - val_accuracy: 0.9211
# Epoch 53/100
# 52/52 [==============================] - 7s 131ms/step - loss: 0.1734 - accuracy: 0.9310 - val_loss: 0.2375 - val_accuracy: 0.9127
# Epoch 54/100
# 52/52 [==============================] - 7s 130ms/step - loss: 0.2354 - accuracy: 0.9123 - val_loss: 0.2115 - val_accuracy: 0.9141
# Epoch 55/100
# 52/52 [==============================] - 7s 131ms/step - loss: 0.1776 - accuracy: 0.9377 - val_loss: 0.2286 - val_accuracy: 0.9169
# Epoch 56/100
# 52/52 [==============================] - 7s 131ms/step - loss: 0.1776 - accuracy: 0.9252 - val_loss: 0.1999 - val_accuracy: 0.9239
# Epoch 57/100
# 52/52 [==============================] - 7s 130ms/step - loss: 0.1655 - accuracy: 0.9352 - val_loss: 0.2076 - val_accuracy: 0.9268
# Epoch 58/100
# 52/52 [==============================] - 7s 131ms/step - loss: 0.1638 - accuracy: 0.9340 - val_loss: 0.2179 - val_accuracy: 0.9197
# Epoch 59/100
# 52/52 [==============================] - 7s 131ms/step - loss: 0.1638 - accuracy: 0.9446 - val_loss: 0.2023 - val_accuracy: 0.9225
# Epoch 60/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.1529 - accuracy: 0.9446 - val_loss: 0.2228 - val_accuracy: 0.9183
# Epoch 61/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.1505 - accuracy: 0.9443 - val_loss: 0.1866 - val_accuracy: 0.9239
# Epoch 62/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.1863 - accuracy: 0.9303 - val_loss: 0.2040 - val_accuracy: 0.9239
# Epoch 63/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.2227 - accuracy: 0.9216 - val_loss: 0.2201 - val_accuracy: 0.9197
# Epoch 64/100
# 52/52 [==============================] - 7s 131ms/step - loss: 0.1852 - accuracy: 0.9299 - val_loss: 0.2012 - val_accuracy: 0.9225
# Epoch 65/100
# 52/52 [==============================] - 7s 131ms/step - loss: 0.1729 - accuracy: 0.9288 - val_loss: 0.2140 - val_accuracy: 0.9197
# Epoch 66/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.1749 - accuracy: 0.9248 - val_loss: 0.2109 - val_accuracy: 0.9169
# Epoch 67/100
# 52/52 [==============================] - 7s 130ms/step - loss: 0.1448 - accuracy: 0.9493 - val_loss: 0.2286 - val_accuracy: 0.9197
# Epoch 68/100
# 52/52 [==============================] - 7s 131ms/step - loss: 0.1305 - accuracy: 0.9487 - val_loss: 0.2179 - val_accuracy: 0.9239
# Epoch 69/100
# 52/52 [==============================] - 7s 131ms/step - loss: 0.1652 - accuracy: 0.9405 - val_loss: 0.2470 - val_accuracy: 0.9127
# Epoch 70/100
# 52/52 [==============================] - 7s 130ms/step - loss: 0.1524 - accuracy: 0.9408 - val_loss: 0.2141 - val_accuracy: 0.9254
# Epoch 71/100
# 52/52 [==============================] - 7s 131ms/step - loss: 0.1241 - accuracy: 0.9545 - val_loss: 0.1977 - val_accuracy: 0.9282
# Epoch 72/100
# 52/52 [==============================] - 7s 131ms/step - loss: 0.1373 - accuracy: 0.9518 - val_loss: 0.2344 - val_accuracy: 0.9239
# Epoch 73/100
# 52/52 [==============================] - 7s 131ms/step - loss: 0.1417 - accuracy: 0.9439 - val_loss: 0.2142 - val_accuracy: 0.9268
# Epoch 74/100
# 52/52 [==============================] - 7s 131ms/step - loss: 0.1276 - accuracy: 0.9511 - val_loss: 0.2207 - val_accuracy: 0.9155
# Epoch 75/100
# 52/52 [==============================] - 7s 130ms/step - loss: 0.1285 - accuracy: 0.9520 - val_loss: 0.2235 - val_accuracy: 0.9282
# Epoch 76/100
# 52/52 [==============================] - 7s 130ms/step - loss: 0.1093 - accuracy: 0.9632 - val_loss: 0.2235 - val_accuracy: 0.9197
# Epoch 77/100
# 52/52 [==============================] - 7s 130ms/step - loss: 0.1472 - accuracy: 0.9438 - val_loss: 0.2098 - val_accuracy: 0.9127
# Epoch 78/100
# 52/52 [==============================] - 7s 131ms/step - loss: 0.1246 - accuracy: 0.9553 - val_loss: 0.2007 - val_accuracy: 0.9197
# Epoch 79/100
# 52/52 [==============================] - 7s 131ms/step - loss: 0.1189 - accuracy: 0.9599 - val_loss: 0.2089 - val_accuracy: 0.9225
# Epoch 80/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.1131 - accuracy: 0.9540 - val_loss: 0.2075 - val_accuracy: 0.9211
# Epoch 81/100
# 52/52 [==============================] - 7s 131ms/step - loss: 0.1230 - accuracy: 0.9555 - val_loss: 0.2328 - val_accuracy: 0.9113
# Epoch 82/100
# 52/52 [==============================] - 7s 131ms/step - loss: 0.1312 - accuracy: 0.9500 - val_loss: 0.2183 - val_accuracy: 0.9268
# Epoch 83/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.1380 - accuracy: 0.9494 - val_loss: 0.2458 - val_accuracy: 0.9155
# Epoch 84/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.0985 - accuracy: 0.9596 - val_loss: 0.2088 - val_accuracy: 0.9282
# Epoch 85/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.1198 - accuracy: 0.9604 - val_loss: 0.2312 - val_accuracy: 0.9141
# Epoch 86/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.1134 - accuracy: 0.9612 - val_loss: 0.2115 - val_accuracy: 0.9183
# Epoch 87/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.0901 - accuracy: 0.9689 - val_loss: 0.2400 - val_accuracy: 0.9070
# Epoch 88/100
# 52/52 [==============================] - 7s 131ms/step - loss: 0.1532 - accuracy: 0.9445 - val_loss: 0.2080 - val_accuracy: 0.9254
# Epoch 89/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.1220 - accuracy: 0.9546 - val_loss: 0.2187 - val_accuracy: 0.9169
# Epoch 90/100
# 52/52 [==============================] - 7s 131ms/step - loss: 0.0943 - accuracy: 0.9691 - val_loss: 0.2404 - val_accuracy: 0.9127
# Epoch 91/100
# 52/52 [==============================] - 7s 131ms/step - loss: 0.0997 - accuracy: 0.9628 - val_loss: 0.2397 - val_accuracy: 0.9155
# Epoch 92/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.1070 - accuracy: 0.9626 - val_loss: 0.2697 - val_accuracy: 0.9211
# Epoch 93/100
# 52/52 [==============================] - 7s 131ms/step - loss: 0.1359 - accuracy: 0.9488 - val_loss: 0.2146 - val_accuracy: 0.9225
# Epoch 94/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.1306 - accuracy: 0.9553 - val_loss: 0.2110 - val_accuracy: 0.9197
# Epoch 95/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.1108 - accuracy: 0.9517 - val_loss: 0.2295 - val_accuracy: 0.9183
# Epoch 96/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.0930 - accuracy: 0.9669 - val_loss: 0.2343 - val_accuracy: 0.9197
# Epoch 97/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.1132 - accuracy: 0.9555 - val_loss: 0.2354 - val_accuracy: 0.9197
# Epoch 98/100
# 52/52 [==============================] - 7s 131ms/step - loss: 0.1134 - accuracy: 0.9576 - val_loss: 0.2431 - val_accuracy: 0.9183
# Epoch 99/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.1130 - accuracy: 0.9630 - val_loss: 0.2636 - val_accuracy: 0.9141
# Epoch 100/100
# 52/52 [==============================] - 7s 132ms/step - loss: 0.1127 - accuracy: 0.9640 - val_loss: 0.2432 - val_accuracy: 0.9197

# %%
plot_loss_acc(history)
# Evaluamos contra test
score = model.evaluate(X_test, y_test, batch_size=16)
print("Loss: {} \nAccuracy: {}%".format(score[0], score[1]*100))
# Out:
# 45/45 [==============================] - 1s 18ms/step - loss: 0.2432 - accuracy: 0.9197
# Loss: 0.24320775270462036
# Accuracy: 91.9718325138092%

# %% [markdown]
# #### **2.2 EVALUACION**

# %%
X_emo_train, X_emo_test, y_emo_train, y_emo_test = processData(array_images_emodb, labels_emodb, 0.30)

# %%
print("Entrenamiento: Datos con dimension {}, y clases con {}".format(X_emo_train.shape, y_emo_train.shape))
print("Test: Datos con dimension {}, y clases con {}".format(X_emo_test.shape, y_emo_test.shape))
# Out:
# Entrenamiento: Datos con dimension (1400, 40, 30, 3), y clases con (1400, 5)
# Test: Datos con dimension (600, 40, 30, 3), y clases con (600, 5)

# %%
from sklearn.metrics import classification_report

predicted_y = model.predict(X_emo_train)
predicted_y = np.argmax(np.round(predicted_y),axis=1)

categorical_labels = np.argmax(y_emo_train, axis=1)


# Mapeo el nombre de las clases
predicted_y = list(map(EMOTION_MAP.get, predicted_y))
categorical_labels = list(map(EMOTION_MAP.get, categorical_labels))

# %%
print(classification_report(categorical_labels, predicted_y))
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.02      0.02      0.02       279
#      disgust       0.00      0.00      0.00       273
#        happy       0.99      1.00      0.99       297
#      neutral       0.00      0.00      0.00       270
#          sad       0.99      1.00      0.99       281
#
#     accuracy                           0.42      1400
#    macro avg       0.40      0.40      0.40      1400
# weighted avg       0.41      0.42      0.41      1400
