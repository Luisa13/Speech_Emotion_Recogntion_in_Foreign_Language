# %%
# Reseteamos todas las variables del entorno
# %reset
# IMPORT LIBRARIES

# Processing
import librosa
import librosa.display
import numpy as np
import random
from tqdm import tqdm

# Visualization
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import IPython.display as ipd

# Files
import os
import joblib
import pickle

# Machine Learning
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.metrics import confusion_matrix
import keras
from keras.utils import np_utils
from tensorflow.keras.utils import to_categorical
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras.models import Sequential, Model, model_from_json
from keras.layers import Dense, Embedding, LSTM
from keras.layers import Input, Flatten, Dropout, Activation, BatchNormalization
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Reshape
import tensorflow as tf

# ####### TEST ####### 
# Scipy
from scipy import signal
from scipy.io import wavfile
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %% [markdown]
# ## **CONFIGURACION DEL ENTORNO**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys  
GPATH = '/content/drive/My Drive/Master/Asignaturas/2 Cuatrimestre/Proyecto/Code/'

if GPATH + '/SpeechEmotionRecognition' in sys.path:
  sys.path.remove(GPATH + '/SpeechEmotionRecognition')

sys.path.insert(0, GPATH + '/SpeechEmotionRecognition')

sys.path
# Out:
# ['/content/drive/My Drive/Master/Asignaturas/2 Cuatrimestre/Proyecto/Code//SpeechEmotionRecognition',
#  '',
#  '/content',
#  '/env/python',
#  '/usr/lib/python37.zip',
#  '/usr/lib/python3.7',
#  '/usr/lib/python3.7/lib-dynload',
#  '/usr/local/lib/python3.7/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.7/dist-packages/IPython/extensions',
#  '/root/.ipython']

# %%
FEATURES_PATH = GPATH + 'SpeechEmotionRecognition/data/processed/features/'
FIGURES_PATH = GPATH + 'SpeechEmotionRecognition/reports/figures/'
# Datasets
SAVEE_PATH = GPATH + 'data/SAVEE/'
TESS_PATH = GPATH + 'data/TESS/'

CAFFE_PATH = GPATH + 'data/CAFFE/'

# Espectogramas
SPECT_IMG = GPATH + 'data/spectrograms/'
SPECTOGRAM_MODEL = SPECT_IMG + 'mfcc_savee_tess/'

# Maps

EMOTION_MAP = {0: 'happy', 1:'disgust', 2:'angry', 3:'neutral', 4:'surprise', 5:'fear', 6:'sad'}
reduced_values = ['angry', 'disgust', 'happy', 'sad', 'neutral']

# %% [markdown]
# ## **1. DATOS**

# %%
# Leemos CAFFE 
EMOTION_CAFFE_MAP = {'Joie':'happy', 'Tristesse':'sad', 'Colere':'angry','Degout':'disgust', 'Neutre':'neutral', 'Surprise':'surprise', 'Peur':'fear'}
emotion=[]
path = []

for folder in os.listdir(CAFFE_PATH):
  path_dir = os.listdir(CAFFE_PATH + folder)
  for filename in path_dir:
    str_path = CAFFE_PATH + str(folder) + '/' + str(filename)
    emotion.append(EMOTION_CAFFE_MAP[folder])
    path.append(str_path)
  
CAFFE_df = pd.DataFrame(columns=['emotion', 'path'])
CAFFE_df['emotion'] = emotion
CAFFE_df['path'] = path

class_distribution = CAFFE_df['emotion'].value_counts()
print( class_distribution )
# Out:
# neutral     36
# surprise    36
# disgust     36
# angry       36
# happy       36
# sad         36
# fear        36
# Name: emotion, dtype: int64

# %%
print( class_distribution )
# Out:
# angry      127
# neutral     79
# happy       71
# sad         62
# disgust     46
# Name: emotion, dtype: int64

# %%
# from src.SpeechDataProcess import SpeechDataProcess
# data = SpeechDataProcess('TESS', TESS_PATH)
# TESS_df = data.read()
# data = SpeechDataProcess('SAVEE', SAVEE_PATH)
# SAVEE_df = data.read()

# %%
emotion=[]
path = []
reduced_values = ['a', 'd', 'h', 'sa', 'n']

for dir in os.listdir(SAVEE_PATH):
  path_dir = os.listdir(SAVEE_PATH + dir) # todos los archivos de audios asociados a un directorio
  for filename in path_dir:
    str_path = SAVEE_PATH + dir + '/' + str(filename)
    label = filename[0]
    if filename[1].isalpha() : label = filename[0] + filename[1] 
    # Solo los valores reducidos
    if label in reduced_values:
      path.append(str_path)
      if(label=='a'):
          emotion.append("angry")
      elif(label=='h'):
          emotion.append("happy")
      elif(label=='f'):
          emotion.append("fear")
      elif(label=='d'):
          emotion.append("disgust")
      elif(label=='n'):
          emotion.append('neutral')
      elif(label=='sa'):
          emotion.append("sad")
      elif(label=='su'):
          emotion.append("surprise")


SAVEE_df = pd.DataFrame(columns=['emotion', 'path'])
SAVEE_df['emotion'] = emotion
SAVEE_df['path'] = path

SAVEE_df['emotion'].unique()
print( SAVEE_df['emotion'].value_counts() )
# Out:
# neutral    120
# sad         60
# disgust     60
# angry       60
# happy       60
# Name: emotion, dtype: int64

# %%
# Leemos TESS

emotion=[]
path = []
reduced_values = ['angry', 'disgust', 'happy', 'sad', 'neutral']
for dir in os.listdir(TESS_PATH):
  path_dir = os.listdir(TESS_PATH + dir) # todos los archivos de audios asociados a un directorio
  label = dir.split('_')[1]
  for filename in path_dir:
    str_path = TESS_PATH + dir + '/' + str(filename)

    # Solo los valores reducidos
    if label.lower() in reduced_values:
      path.append(str_path)
      emotion.append(label.lower())


TESS_df = pd.DataFrame(columns=['emotion', 'path'])
TESS_df['emotion'] = emotion
TESS_df['path'] = path

print( "Size of the dataset: {} \n".format(len(TESS_df)) )
print( TESS_df['emotion'].value_counts() )
# TESS_df.sample(5)
# Out:
# Size of the dataset: 2000
#
# neutral    400
# happy      400
# disgust    400
# sad        400
# angry      400
# Name: emotion, dtype: int64

# %%
if len(TESS_df.emotion.unique()) == len(SAVEE_df.emotion.unique()) and len(TESS_df.emotion.unique()) == len(EMODDB_df.emotion.unique()):
  print("Todas las dimensiones son correctas")
# Out:
# Todas las dimensiones son correctas

# %% [markdown]
# ### **1.2 EXTRACCION DE ESPECTROGRAMAS**

# %%
from src.MFCC import MFCC

# %%
features_spectMFCC_SAVEE = MFCC(df_data = SAVEE_df, dataset_name = "SAVEE")
features_spectMFCC_TESS = MFCC(df_data = TESS_df, dataset_name = "TESS")

features_spectMFCC_CAFFE = MFCC(df_data = CAFFE_df, dataset_name = "CAFFE")
# list_images, labels = featuresMFCC_SAVEE.load_images(IMG_MFCC, (40,40))

# %%
# # Genero los espectrogramas
# features_spectMFCC_SAVEE.generate_spectrograms(SPECT_IMG)
# features_spectMFCC_TESS.generate_spectrograms(SPECT_IMG)

# # Genero los espectogramas de test
# features_spectMFCC_CAFFE.generate_spectrograms(SPECT_IMG + 'test_caffe/')

# %%
list_images_savee_tess, labels = features_spectMFCC_TESS.load_spectograms_dataset(SPECTOGRAM_MODEL, (30,40))
# Out:
# Leídas 460 espectogramas pertenecientes a angry
# Leídas 460 espectogramas pertenecientes a disgust
# Leídas 460 espectogramas pertenecientes a fear
# Leídas 460 espectogramas pertenecientes a happy
# Leídas 524 espectogramas pertenecientes a neutral
# Leídas 460 espectogramas pertenecientes a sad
# Leídas 460 espectogramas pertenecientes a surprise

# %%
array_images_savee_tess = np.array(list_images_savee_tess)
print("{} imagenes con dimension {}".format(array_images_savee_tess.shape[0], array_images_savee_tess.shape[1:]))
# Out:
# 3284 imagenes con dimension (40, 30, 3)

# %%
list_images_caffe, labels_caffe = features_spectMFCC_CAFFE.load_spectograms_dataset(SPECT_IMG + 'test_caffe/', (30,40))
array_images_caffe= np.array(list_images_caffe)
# Out:
# Leídas 36 espectogramas pertenecientes a happy
# Leídas 36 espectogramas pertenecientes a disgust
# Leídas 36 espectogramas pertenecientes a angry
# Leídas 36 espectogramas pertenecientes a neutral
# Leídas 36 espectogramas pertenecientes a surprise
# Leídas 36 espectogramas pertenecientes a fear
# Leídas 36 espectogramas pertenecientes a sad

# %% [markdown]
# ## **2. DEFINICION DEL MODELO**

# %%
def get_model_LSTM_CNN(shape, classes):
  model = Sequential()

  # 1 Capa CNN 2D
  model.add(Conv2D(64, (3, 3), padding = 'same', input_shape = shape, activation = 'relu')) # (128, 128, 3)
  model.add(MaxPooling2D(pool_size = (2, 2)))

  # 2 Capa CNN 2D
  model.add(Conv2D(64, (3, 3), padding = 'same', activation = 'relu'))
  model.add(MaxPooling2D(pool_size = (2, 2)))

  # 3 Capa CNN 2D
  model.add(Conv2D(64, (3, 3), padding = 'same', activation = 'relu'))
  model.add(MaxPooling2D(pool_size = (2, 2)))

  # Capa Flatten
  model.add(Flatten())
  model.add(Dropout(rate = 0.5))

  # Capas LSTM 1D
  model.add(Reshape((1, 960))) 
  model.add(LSTM(units = 50, return_sequences = True, dropout = 0.5))
  model.add(LSTM(units = 20, return_sequences = False, dropout = 0.5))

  model.add(Dense(classes, activation = 'softmax'))

  return model


def plot_loss_acc(history):
  # Mostramos la grafica loss 
  fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
  ax1.plot(history.history['loss'])
  ax1.plot(history.history['val_loss'])
  ax1.set_title('Loss')
  ax1.set(xlabel='epoch', ylabel='loss')
  ax1.legend(['train', 'test'], loc='upper right')

  # Mostramos la grafica accuracy
  ax2.plot(history.history['accuracy'])
  ax2.plot(history.history['val_accuracy'])
  ax2.set_title('Validation')
  ax2.set(xlabel='epoch', ylabel='acc')

  ax2.legend(['train', 'test'], loc='lower right')


def processData(data, labels, test_size = 0.25):
  X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=test_size, shuffle=True, random_state=42)

  # one hot encoding 
  lb = LabelEncoder()
  y_train = np_utils.to_categorical(lb.fit_transform(y_train))
  y_test = np_utils.to_categorical(lb.fit_transform(y_test))

  # Normalization as per the standard NN process
  mean = np.mean(X_train, axis=0)
  std = np.std(X_train, axis=0)

  X_train = (X_train - mean)/std
  X_test = (X_test - mean)/std

  return X_train, X_test, y_train, y_test

# %% [markdown]
# #### **2.1 ENTRENAMIENTO**

# %%
X_train, X_test, y_train, y_test = processData(array_images_savee_tess, labels, 0.3)

# %%
print("Entrenamiento: Datos con dimension {}, y clases con {}".format(X_train.shape, y_train.shape))
print("Test: Datos con dimension {}, y clases con {}".format(X_test.shape, y_test.shape))
# Out:
# Entrenamiento: Datos con dimension (2298, 40, 30, 3), y clases con (2298, 7)
# Test: Datos con dimension (986, 40, 30, 3), y clases con (986, 7)

# %%
model = get_model_LSTM_CNN(X_train.shape[1:], y_train.shape[1])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 40, 30, 64)        1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 20, 15, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 20, 15, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 7, 64)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 10, 7, 64)         36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 3, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 960)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 960)               0
# _________________________________________________________________
# reshape (Reshape)            (None, 1, 960)            0
# _________________________________________________________________
# lstm (LSTM)                  (None, 1, 50)             202200
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 20)                5680
# _________________________________________________________________
# dense (Dense)                (None, 7)                 147
# =================================================================
# Total params: 283,675
# Trainable params: 283,675
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(X_train, y_train, 
                      batch_size=32, 
                      epochs=100, 
                      validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 72/72 [==============================] - 34s 152ms/step - loss: 1.9334 - accuracy: 0.1716 - val_loss: 1.8860 - val_accuracy: 0.2901
# Epoch 2/100
# 72/72 [==============================] - 9s 132ms/step - loss: 1.8872 - accuracy: 0.2379 - val_loss: 1.8205 - val_accuracy: 0.3357
# Epoch 3/100
# 72/72 [==============================] - 9s 132ms/step - loss: 1.8260 - accuracy: 0.2667 - val_loss: 1.6548 - val_accuracy: 0.3742
# Epoch 4/100
# 72/72 [==============================] - 10s 132ms/step - loss: 1.6735 - accuracy: 0.3622 - val_loss: 1.4425 - val_accuracy: 0.5700
# Epoch 5/100
# 72/72 [==============================] - 9s 130ms/step - loss: 1.4094 - accuracy: 0.5313 - val_loss: 1.0088 - val_accuracy: 0.7140
# Epoch 6/100
# 72/72 [==============================] - 9s 131ms/step - loss: 1.1411 - accuracy: 0.6079 - val_loss: 0.8114 - val_accuracy: 0.7860
# Epoch 7/100
# 72/72 [==============================] - 9s 132ms/step - loss: 0.9274 - accuracy: 0.6880 - val_loss: 0.6864 - val_accuracy: 0.7911
# Epoch 8/100
# 72/72 [==============================] - 10s 132ms/step - loss: 0.7817 - accuracy: 0.7384 - val_loss: 0.5801 - val_accuracy: 0.8256
# Epoch 9/100
# 72/72 [==============================] - 10s 132ms/step - loss: 0.7052 - accuracy: 0.7699 - val_loss: 0.5214 - val_accuracy: 0.8428
# Epoch 10/100
# 72/72 [==============================] - 10s 133ms/step - loss: 0.6527 - accuracy: 0.7778 - val_loss: 0.4545 - val_accuracy: 0.8529
# Epoch 11/100
# 72/72 [==============================] - 9s 131ms/step - loss: 0.5731 - accuracy: 0.8188 - val_loss: 0.4346 - val_accuracy: 0.8550
# Epoch 12/100
# 72/72 [==============================] - 9s 132ms/step - loss: 0.5133 - accuracy: 0.8275 - val_loss: 0.3890 - val_accuracy: 0.8682
# Epoch 13/100
# 72/72 [==============================] - 10s 132ms/step - loss: 0.4965 - accuracy: 0.8214 - val_loss: 0.3661 - val_accuracy: 0.8732
# Epoch 14/100
# 72/72 [==============================] - 9s 131ms/step - loss: 0.4405 - accuracy: 0.8550 - val_loss: 0.3759 - val_accuracy: 0.8682
# Epoch 15/100
# 72/72 [==============================] - 10s 132ms/step - loss: 0.4527 - accuracy: 0.8482 - val_loss: 0.3340 - val_accuracy: 0.8783
# Epoch 16/100
# 72/72 [==============================] - 9s 131ms/step - loss: 0.4249 - accuracy: 0.8625 - val_loss: 0.3416 - val_accuracy: 0.8753
# Epoch 17/100
# 72/72 [==============================] - 9s 132ms/step - loss: 0.3953 - accuracy: 0.8603 - val_loss: 0.3256 - val_accuracy: 0.8824
# Epoch 18/100
# 72/72 [==============================] - 9s 131ms/step - loss: 0.3929 - accuracy: 0.8664 - val_loss: 0.3216 - val_accuracy: 0.8824
# Epoch 19/100
# 72/72 [==============================] - 9s 131ms/step - loss: 0.3715 - accuracy: 0.8750 - val_loss: 0.3131 - val_accuracy: 0.8813
# Epoch 20/100
# 72/72 [==============================] - 10s 134ms/step - loss: 0.3425 - accuracy: 0.8829 - val_loss: 0.3073 - val_accuracy: 0.8824
# Epoch 21/100
# 72/72 [==============================] - 10s 132ms/step - loss: 0.3399 - accuracy: 0.8793 - val_loss: 0.3116 - val_accuracy: 0.8824
# Epoch 22/100
# 72/72 [==============================] - 9s 132ms/step - loss: 0.3428 - accuracy: 0.8849 - val_loss: 0.3043 - val_accuracy: 0.8905
# Epoch 23/100
# 72/72 [==============================] - 10s 133ms/step - loss: 0.2975 - accuracy: 0.8998 - val_loss: 0.3144 - val_accuracy: 0.8813
# Epoch 24/100
# 72/72 [==============================] - 9s 132ms/step - loss: 0.3426 - accuracy: 0.8762 - val_loss: 0.2959 - val_accuracy: 0.8925
# Epoch 25/100
# 72/72 [==============================] - 9s 132ms/step - loss: 0.3308 - accuracy: 0.8817 - val_loss: 0.3065 - val_accuracy: 0.8874
# Epoch 26/100
# 72/72 [==============================] - 9s 131ms/step - loss: 0.3455 - accuracy: 0.8706 - val_loss: 0.2883 - val_accuracy: 0.8976
# Epoch 27/100
# 72/72 [==============================] - 9s 131ms/step - loss: 0.3155 - accuracy: 0.8843 - val_loss: 0.2867 - val_accuracy: 0.8895
# Epoch 28/100
# 72/72 [==============================] - 9s 132ms/step - loss: 0.3139 - accuracy: 0.8895 - val_loss: 0.2876 - val_accuracy: 0.8895
# Epoch 29/100
# 72/72 [==============================] - 10s 133ms/step - loss: 0.3155 - accuracy: 0.8927 - val_loss: 0.2871 - val_accuracy: 0.8925
# Epoch 30/100
# 72/72 [==============================] - 10s 134ms/step - loss: 0.3078 - accuracy: 0.8878 - val_loss: 0.2835 - val_accuracy: 0.8925
# Epoch 31/100
# 72/72 [==============================] - 10s 133ms/step - loss: 0.3254 - accuracy: 0.8840 - val_loss: 0.2901 - val_accuracy: 0.8874
# Epoch 32/100
# 72/72 [==============================] - 9s 131ms/step - loss: 0.3060 - accuracy: 0.8911 - val_loss: 0.2791 - val_accuracy: 0.8925
# Epoch 33/100
# 72/72 [==============================] - 9s 130ms/step - loss: 0.3171 - accuracy: 0.8799 - val_loss: 0.2784 - val_accuracy: 0.8915
# Epoch 34/100
# 72/72 [==============================] - 9s 131ms/step - loss: 0.2602 - accuracy: 0.8999 - val_loss: 0.2792 - val_accuracy: 0.8905
# Epoch 35/100
# 72/72 [==============================] - 9s 131ms/step - loss: 0.2724 - accuracy: 0.9056 - val_loss: 0.2847 - val_accuracy: 0.8966
# Epoch 36/100
# 72/72 [==============================] - 9s 132ms/step - loss: 0.2856 - accuracy: 0.8985 - val_loss: 0.2665 - val_accuracy: 0.8905
# Epoch 37/100
# 72/72 [==============================] - 9s 131ms/step - loss: 0.2832 - accuracy: 0.8940 - val_loss: 0.3005 - val_accuracy: 0.8905
# Epoch 38/100
# 72/72 [==============================] - 9s 131ms/step - loss: 0.2735 - accuracy: 0.8963 - val_loss: 0.2801 - val_accuracy: 0.8895
# Epoch 39/100
# 72/72 [==============================] - 9s 131ms/step - loss: 0.2780 - accuracy: 0.8980 - val_loss: 0.2839 - val_accuracy: 0.8884
# Epoch 40/100
# 72/72 [==============================] - 9s 131ms/step - loss: 0.2667 - accuracy: 0.9072 - val_loss: 0.2753 - val_accuracy: 0.8935
# Epoch 41/100
# 72/72 [==============================] - 9s 131ms/step - loss: 0.2465 - accuracy: 0.9063 - val_loss: 0.2738 - val_accuracy: 0.8986
# Epoch 42/100
# 72/72 [==============================] - 9s 131ms/step - loss: 0.2693 - accuracy: 0.8967 - val_loss: 0.2716 - val_accuracy: 0.9006
# Epoch 43/100
# 72/72 [==============================] - 9s 131ms/step - loss: 0.2942 - accuracy: 0.8927 - val_loss: 0.2919 - val_accuracy: 0.8884
# Epoch 44/100
# 72/72 [==============================] - 9s 132ms/step - loss: 0.2618 - accuracy: 0.9016 - val_loss: 0.2765 - val_accuracy: 0.8986
# Epoch 45/100
# 72/72 [==============================] - 9s 132ms/step - loss: 0.2353 - accuracy: 0.9161 - val_loss: 0.2832 - val_accuracy: 0.9016
# Epoch 46/100
# 72/72 [==============================] - 9s 132ms/step - loss: 0.3014 - accuracy: 0.8893 - val_loss: 0.2827 - val_accuracy: 0.8884
# Epoch 47/100
# 72/72 [==============================] - 9s 131ms/step - loss: 0.2431 - accuracy: 0.9147 - val_loss: 0.2728 - val_accuracy: 0.8976
# Epoch 48/100
# 72/72 [==============================] - 9s 131ms/step - loss: 0.2283 - accuracy: 0.9134 - val_loss: 0.2953 - val_accuracy: 0.8864
# Epoch 49/100
# 72/72 [==============================] - 10s 132ms/step - loss: 0.2663 - accuracy: 0.8956 - val_loss: 0.2741 - val_accuracy: 0.8935
# Epoch 50/100
# 72/72 [==============================] - 9s 131ms/step - loss: 0.2465 - accuracy: 0.9068 - val_loss: 0.2882 - val_accuracy: 0.8925
# Epoch 51/100
# 72/72 [==============================] - 9s 131ms/step - loss: 0.2835 - accuracy: 0.8981 - val_loss: 0.2699 - val_accuracy: 0.9006
# Epoch 52/100
# 72/72 [==============================] - 9s 132ms/step - loss: 0.2472 - accuracy: 0.9143 - val_loss: 0.2749 - val_accuracy: 0.8966
# Epoch 53/100
# 72/72 [==============================] - 9s 131ms/step - loss: 0.2323 - accuracy: 0.9159 - val_loss: 0.2594 - val_accuracy: 0.8986
# Epoch 54/100
# 72/72 [==============================] - 9s 131ms/step - loss: 0.2596 - accuracy: 0.8994 - val_loss: 0.2841 - val_accuracy: 0.8884
# Epoch 55/100
# 72/72 [==============================] - 10s 133ms/step - loss: 0.2560 - accuracy: 0.9026 - val_loss: 0.2686 - val_accuracy: 0.9057
# Epoch 56/100
# 72/72 [==============================] - 10s 132ms/step - loss: 0.2410 - accuracy: 0.9067 - val_loss: 0.2729 - val_accuracy: 0.9016
# Epoch 57/100
# 72/72 [==============================] - 10s 133ms/step - loss: 0.2195 - accuracy: 0.9194 - val_loss: 0.2731 - val_accuracy: 0.8976
# Epoch 58/100
# 72/72 [==============================] - 9s 132ms/step - loss: 0.2635 - accuracy: 0.9011 - val_loss: 0.2844 - val_accuracy: 0.8935
# Epoch 59/100
# 72/72 [==============================] - 9s 131ms/step - loss: 0.2256 - accuracy: 0.9043 - val_loss: 0.2579 - val_accuracy: 0.9037
# Epoch 60/100
# 72/72 [==============================] - 9s 132ms/step - loss: 0.2471 - accuracy: 0.9079 - val_loss: 0.2693 - val_accuracy: 0.8996
# Epoch 61/100
# 72/72 [==============================] - 10s 133ms/step - loss: 0.2134 - accuracy: 0.9209 - val_loss: 0.2726 - val_accuracy: 0.9016
# Epoch 62/100
# 72/72 [==============================] - 10s 133ms/step - loss: 0.2306 - accuracy: 0.9163 - val_loss: 0.2800 - val_accuracy: 0.8955
# Epoch 63/100
# 72/72 [==============================] - 9s 132ms/step - loss: 0.2550 - accuracy: 0.9067 - val_loss: 0.2487 - val_accuracy: 0.9016
# Epoch 64/100
# 72/72 [==============================] - 9s 131ms/step - loss: 0.2317 - accuracy: 0.9129 - val_loss: 0.2449 - val_accuracy: 0.9037
# Epoch 65/100
# 72/72 [==============================] - 9s 132ms/step - loss: 0.2367 - accuracy: 0.9145 - val_loss: 0.2496 - val_accuracy: 0.9077
# Epoch 66/100
# 72/72 [==============================] - 9s 131ms/step - loss: 0.2261 - accuracy: 0.9138 - val_loss: 0.2553 - val_accuracy: 0.9057
# Epoch 67/100
# 72/72 [==============================] - 9s 131ms/step - loss: 0.2389 - accuracy: 0.9086 - val_loss: 0.2615 - val_accuracy: 0.8996
# Epoch 68/100
# 72/72 [==============================] - 9s 132ms/step - loss: 0.2153 - accuracy: 0.9177 - val_loss: 0.2479 - val_accuracy: 0.9016
# Epoch 69/100
# 72/72 [==============================] - 9s 132ms/step - loss: 0.2261 - accuracy: 0.9150 - val_loss: 0.2664 - val_accuracy: 0.8945
# Epoch 70/100
# 72/72 [==============================] - 9s 131ms/step - loss: 0.2265 - accuracy: 0.9186 - val_loss: 0.2436 - val_accuracy: 0.9067
# Epoch 71/100
# 72/72 [==============================] - 9s 132ms/step - loss: 0.1892 - accuracy: 0.9349 - val_loss: 0.2920 - val_accuracy: 0.8874
# Epoch 72/100
# 72/72 [==============================] - 9s 131ms/step - loss: 0.2216 - accuracy: 0.9092 - val_loss: 0.2533 - val_accuracy: 0.9037
# Epoch 73/100
# 72/72 [==============================] - 10s 132ms/step - loss: 0.2169 - accuracy: 0.9156 - val_loss: 0.2442 - val_accuracy: 0.9037
# Epoch 74/100
# 72/72 [==============================] - 10s 133ms/step - loss: 0.2095 - accuracy: 0.9189 - val_loss: 0.2486 - val_accuracy: 0.9037
# Epoch 75/100
# 72/72 [==============================] - 10s 132ms/step - loss: 0.2299 - accuracy: 0.9140 - val_loss: 0.2567 - val_accuracy: 0.9057
# Epoch 76/100
# 72/72 [==============================] - 10s 132ms/step - loss: 0.2177 - accuracy: 0.9179 - val_loss: 0.2639 - val_accuracy: 0.9016
# Epoch 77/100
# 72/72 [==============================] - 9s 132ms/step - loss: 0.2021 - accuracy: 0.9242 - val_loss: 0.2583 - val_accuracy: 0.9016
# Epoch 78/100
# 72/72 [==============================] - 9s 132ms/step - loss: 0.2232 - accuracy: 0.9182 - val_loss: 0.2590 - val_accuracy: 0.8976
# Epoch 79/100
# 72/72 [==============================] - 10s 133ms/step - loss: 0.1929 - accuracy: 0.9298 - val_loss: 0.2638 - val_accuracy: 0.8986
# Epoch 80/100
# 72/72 [==============================] - 10s 132ms/step - loss: 0.2261 - accuracy: 0.9156 - val_loss: 0.2472 - val_accuracy: 0.9067
# Epoch 81/100
# 72/72 [==============================] - 10s 134ms/step - loss: 0.2224 - accuracy: 0.9207 - val_loss: 0.2784 - val_accuracy: 0.8966
# Epoch 82/100
# 72/72 [==============================] - 10s 133ms/step - loss: 0.2302 - accuracy: 0.9146 - val_loss: 0.2535 - val_accuracy: 0.8986
# Epoch 83/100
# 72/72 [==============================] - 10s 134ms/step - loss: 0.2073 - accuracy: 0.9222 - val_loss: 0.2562 - val_accuracy: 0.9047
# Epoch 84/100
# 72/72 [==============================] - 10s 133ms/step - loss: 0.2207 - accuracy: 0.9088 - val_loss: 0.2493 - val_accuracy: 0.9037
# Epoch 85/100
# 72/72 [==============================] - 10s 134ms/step - loss: 0.2079 - accuracy: 0.9204 - val_loss: 0.2510 - val_accuracy: 0.8986
# Epoch 86/100
# 72/72 [==============================] - 10s 134ms/step - loss: 0.1515 - accuracy: 0.9463 - val_loss: 0.2548 - val_accuracy: 0.8996
# Epoch 87/100
# 72/72 [==============================] - 10s 133ms/step - loss: 0.2043 - accuracy: 0.9275 - val_loss: 0.2708 - val_accuracy: 0.9026
# Epoch 88/100
# 72/72 [==============================] - 10s 132ms/step - loss: 0.1943 - accuracy: 0.9301 - val_loss: 0.2799 - val_accuracy: 0.9026
# Epoch 89/100
# 72/72 [==============================] - 10s 134ms/step - loss: 0.2060 - accuracy: 0.9256 - val_loss: 0.2631 - val_accuracy: 0.9026
# Epoch 90/100
# 72/72 [==============================] - 10s 133ms/step - loss: 0.2198 - accuracy: 0.9176 - val_loss: 0.2722 - val_accuracy: 0.8935
# Epoch 91/100
# 72/72 [==============================] - 9s 132ms/step - loss: 0.2025 - accuracy: 0.9218 - val_loss: 0.2735 - val_accuracy: 0.8986
# Epoch 92/100
# 72/72 [==============================] - 9s 132ms/step - loss: 0.2225 - accuracy: 0.9276 - val_loss: 0.2702 - val_accuracy: 0.8935
# Epoch 93/100
# 72/72 [==============================] - 10s 133ms/step - loss: 0.2051 - accuracy: 0.9312 - val_loss: 0.2788 - val_accuracy: 0.9016
# Epoch 94/100
# 72/72 [==============================] - 9s 131ms/step - loss: 0.1934 - accuracy: 0.9294 - val_loss: 0.2625 - val_accuracy: 0.9026
# Epoch 95/100
# 72/72 [==============================] - 9s 132ms/step - loss: 0.2446 - accuracy: 0.9100 - val_loss: 0.2506 - val_accuracy: 0.9097
# Epoch 96/100
# 72/72 [==============================] - 9s 131ms/step - loss: 0.1816 - accuracy: 0.9380 - val_loss: 0.2620 - val_accuracy: 0.9057
# Epoch 97/100
# 72/72 [==============================] - 10s 132ms/step - loss: 0.1923 - accuracy: 0.9405 - val_loss: 0.2793 - val_accuracy: 0.8986
# Epoch 98/100
# 72/72 [==============================] - 10s 133ms/step - loss: 0.1790 - accuracy: 0.9371 - val_loss: 0.2789 - val_accuracy: 0.8986
# Epoch 99/100
# 72/72 [==============================] - 10s 133ms/step - loss: 0.2030 - accuracy: 0.9254 - val_loss: 0.2701 - val_accuracy: 0.9026
# Epoch 100/100
# 72/72 [==============================] - 10s 133ms/step - loss: 0.1872 - accuracy: 0.9310 - val_loss: 0.2536 - val_accuracy: 0.9006

# %%
plot_loss_acc(history)
# Evaluamos contra test
score = model.evaluate(X_test, y_test, batch_size=16)
print("Loss: {} \nAccuracy: {}%".format(score[0], score[1]*100))
# Out:
# 62/62 [==============================] - 1s 18ms/step - loss: 0.2536 - accuracy: 0.9006
# Loss: 0.25356683135032654
# Accuracy: 90.06085395812988%

# %% [markdown]
# #### **2.2 EVALUACION**

# %%
X_caff_train, X_caff_test, y_caff_train, y_caff_test = processData(array_images_caffe, labels_caffe, 0.2)

# %%
print("Entrenamiento: Datos con dimension {}, y clases con {}".format(X_caff_train.shape, y_caff_train.shape))
print("Test: Datos con dimension {}, y clases con {}".format(X_caff_test.shape, y_caff_test.shape))
# Out:
# Entrenamiento: Datos con dimension (201, 40, 30, 3), y clases con (201, 7)
# Test: Datos con dimension (51, 40, 30, 3), y clases con (51, 7)

# %%
from sklearn.metrics import classification_report

predicted_y = model.predict(X_caff_train)
predicted_y = np.argmax(np.round(predicted_y),axis=1)

categorical_labels = np.argmax(y_caff_train, axis=1)


# Mapeo el nombre de las clases
predicted_y = list(map(EMOTION_MAP.get, predicted_y))
categorical_labels = list(map(EMOTION_MAP.get, categorical_labels))

# %%
print(classification_report(categorical_labels, predicted_y))
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.22      0.41      0.29        32
#      disgust       0.20      0.30      0.24        30
#         fear       0.00      0.00      0.00        29
#        happy       0.09      0.08      0.09        25
#      neutral       0.00      0.00      0.00        26
#          sad       0.16      0.29      0.20        31
#     surprise       0.00      0.00      0.00        28
#
#     accuracy                           0.16       201
#    macro avg       0.10      0.15      0.12       201
# weighted avg       0.10      0.16      0.12       201
