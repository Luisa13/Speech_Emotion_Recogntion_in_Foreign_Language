# %% [markdown]
# # **SER Tecnicas de Data Augmentation**
#
# ## English
# El siguiente analisis presenta una clasificacion emocional del discurso, reconociendo 7 emociones (enfado, sorpresa, asco, miedo, felicidad, tristeza y neutral) para el idioma **ingles**.
#
# Este notebook es una continuacion del estudio que se hace sobre las emociones en la prosodia de la voz, explorando esta vez, tecnicas de aumento de datos.
#
# Luisa Sanchez Avivar
#     _luisasanavi@gmail.com_

# %%
# IMPORT LIBRARIES

# Processing
import librosa
import librosa.display
import numpy as np
import random
from tqdm import tqdm

# Visualization
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import IPython.display as ipd

# Files
import os
import joblib

# Machine Learning
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.metrics import confusion_matrix
import keras
from keras.utils import np_utils, to_categorical
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras.models import Sequential, Model, model_from_json
from keras.layers import Dense, Embedding, LSTM
from keras.layers import Input, Flatten, Dropout, Activation, BatchNormalization
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D
import tensorflow as tf

# ####### TEST ####### 
# Scipy
from scipy import signal
from scipy.io import wavfile

# %%
AUDIO_DATA_PATH = 'data/'
GPATH = '/content/drive/MyDrive/Master/Asignaturas/2 Cuatrimestre/Proyecto/Code/'
LPATH_DATA = 'SpeechEmotionRecognition/data/processed/features/' 
SAMPLE_FILE = "03-01-01-01-01-01-01.wav"

# Maps
EMOTION_MAP = {1:'neutral', 2:'calm', 3:'happy', 4:'sad', 5:'angry', 6:'fear', 7:'disgust', 8:'surprise'}
INTENSITY_MAP = {1:'normal', 2:'strong'}

# %% [markdown]
# ## **1. CARGA DE DATOS**
# Para este analisis utilizare el dataset de [RAVDESS](https://zenodo.org/record/1188976.) (Ryerson Audio-Visual Database of Emotional Speech and Song), el cual contiene 7356 archivos (24.8 GB) entre los cuales podemos encontrar 3 modalidades: **solo audio** (en 16 bit, 48 kHz y en formato .wav), **audio-video** (720p H.264, AAC 48kHz, .mp4) y **solo video** sin sonido.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dir_list = os.listdir(GPATH + AUDIO_DATA_PATH)
dir_list.sort()

print(dir_list)

emotion = []
gender = []
intensity = []
path = []

# Extraemos de cada archivo de sonido sus datos
for dir in dir_list:
  path_dir = os.listdir(GPATH + AUDIO_DATA_PATH + dir) # todos los archivos de audios asociados a un directorio
  for filepath in path_dir:
    info_vector = filepath.split('.')[0].split('-')
    n_emotion = int(info_vector[2])
    n_gender = int(info_vector[6])
    n_intensity = int(info_vector[3])
    str_path = GPATH + AUDIO_DATA_PATH + dir + '/' + str(filepath)
    path.append(str_path)
    emotion.append(n_emotion)
    intensity.append(n_intensity)
    if n_gender%2 == 0:
      gender.append('female')
    else:
      gender.append('male')

# Construimos el data frame
EnglishSpeech_df = pd.DataFrame(columns=['emotion', 'gender', 'intensity', 'path'])
EnglishSpeech_df['emotion'] = emotion
EnglishSpeech_df['gender'] = gender
EnglishSpeech_df['intensity'] = intensity
EnglishSpeech_df['path'] = path
EnglishSpeech_df['emotion'] = EnglishSpeech_df['emotion'].map(EMOTION_MAP) 
EnglishSpeech_df['intensity'] = EnglishSpeech_df['intensity'].map(INTENSITY_MAP)


print("Size of the dataset: {} \n".format(len(EnglishSpeech_df)))
class_distribution = EnglishSpeech_df['emotion'].value_counts()
print(class_distribution)
# Out:
# ['Actor_01', 'Actor_02', 'Actor_03', 'Actor_04', 'Actor_05', 'Actor_06', 'Actor_07', 'Actor_08', 'Actor_09', 'Actor_10', 'Actor_11', 'Actor_12', 'Actor_13', 'Actor_14', 'Actor_15', 'Actor_16', 'Actor_17', 'Actor_18', 'Actor_19', 'Actor_20', 'Actor_21', 'Actor_22', 'Actor_23', 'Actor_24', 'RAVDESS']
# Size of the dataset: 1440
#
# happy       192
# sad         192
# disgust     192
# angry       192
# calm        192
# fear        192
# surprise    192
# neutral      96
# Name: emotion, dtype: int64

# %%
# Imprimimos una muestra de 10 filas aleatorias
EnglishSpeech_df.sample(n = 10)
# Out:
#        emotion  ...                                               path
# 1271   neutral  ...  /content/drive/MyDrive/Master/Asignaturas/2 Cu...
# 381      angry  ...  /content/drive/MyDrive/Master/Asignaturas/2 Cu...
# 1101     happy  ...  /content/drive/MyDrive/Master/Asignaturas/2 Cu...
# 740      angry  ...  /content/drive/MyDrive/Master/Asignaturas/2 Cu...
# 536   surprise  ...  /content/drive/MyDrive/Master/Asignaturas/2 Cu...
# 634      angry  ...  /content/drive/MyDrive/Master/Asignaturas/2 Cu...
# 94       angry  ...  /content/drive/MyDrive/Master/Asignaturas/2 Cu...
# 834    disgust  ...  /content/drive/MyDrive/Master/Asignaturas/2 Cu...
# 964       calm  ...  /content/drive/MyDrive/Master/Asignaturas/2 Cu...
# 236   surprise  ...  /content/drive/MyDrive/Master/Asignaturas/2 Cu...
#
# [10 rows x 4 columns]

# %% [markdown]
# # **2. EXPLORACION DE LOS DATOS**

# %% [markdown]
# ### **2.1 EXPOSICION DE UNA MUESTRA ALEATORIA**

# %%
def plot_audio_waveform(audio_sample):
  '''
  Muestra la forma de la onda sonora a partir de una muestra.

  Arguments
  ---------
  audio_sample: dataFrame
    Muestra de audio 
  
  '''
  sample, sampling_rate = librosa.load(audio_sample)
  plt.figure(figsize=(12, 4))
  librosa.display.waveplot(sample, sr=sampling_rate)
  print(len(sample))
  

def log_specgram(audio_sample):
  '''
  Muestra el espectograma a partir de una muestra de audio

  Arguments
  ---------
  audio_sample: dataFrame
    Muestra de audio
  '''
  sample, sampling_rate = librosa.load(audio_sample)
  return  __log_specgram(sample, sampling_rate)


def __log_specgram(audio, sample_rate, window_size=20,
                 step_size=10, eps=1e-10):
  '''
  Imprime el especograma de una muestra de audio en una ventana de tiempo
  
  Arguments
  ---------
  audio: np.ndarray
    Muestra de audio
  sample_rate: int, optional
    Frecuencia de muestreo de la muestra de audio
  window_size: int, optional

  step_size: int, optional
  
  eps: int, optional
  '''
  nperseg = int(round(window_size * sample_rate / 1e3))
  noverlap = int(round(step_size * sample_rate / 1e3))
  freqs, times, spec = signal.spectrogram(audio,
                                    fs=sample_rate,
                                    window='hann',
                                    nperseg=nperseg,
                                    noverlap=noverlap,
                                    detrend=False)
  return freqs, times, np.log(spec.T.astype(np.float32) + eps)

# %%
random_sample = EnglishSpeech_df.path[random.randint(0, len(EnglishSpeech_df))]
print("Random audio sample: {}".format(random_sample))
# Dibuja la grafica de la onda sonora
plot_audio_waveform(random_sample)
# Esta es la muestra sonora
ipd.Audio(random_sample, rate=16000)
# Out:
# Random audio sample: /content/drive/MyDrive/Master/Asignaturas/2 Cuatrimestre/Proyecto/Code/data/Actor_19/03-01-06-01-01-01-19.wav
# 81667
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### **2.2 COMPARATIVA DE TODAS LAS EMOCIONES**
# Ahora que hemos conseguido extraer la grafica de una determinada muestra de sonido, vamos a comparar la graficas correspondientes a las muestras de sonido de distintas emociones respectivamente. Para ello vamos a distinguir por genero, ya que podria suponer una diferencia.

# %%
def plot_all_emotion_waveforms(gender, rows = 3, cols = 3):
  '''
  Muestra los graficos para todas las emociones con su correspondiente 
  etiqueta del dataset para un mismo genero (female/ male)
  
  Arguments
  --------- 
    gender: str
      Genero del actor en el audio
    rows:  int, optional
      Filas en las que se muestra. 5 por defecto
    cols: int, optional
      Columnas en las que se muestra. 2 por defecto
    
  '''
  labels = list(EnglishSpeech_df['emotion'].unique())
  files = dict()
  if not gender:
    return -1

  # Seleccionamos una muestra aleatoria correspondiente a cada emocion
  for label in labels:
    # Escogemos un archivo de audio al azar que cumpla estas dos condiciones
    index = EnglishSpeech_df[(EnglishSpeech_df['emotion'] == label) & 
                            (EnglishSpeech_df['gender'] == gender)].sample(n = 1).index[0]
    emotion_file = EnglishSpeech_df.iloc[index].path
    files[label] = emotion_file

  # Mostramos las diferentes waveforms
  fig = plt.figure(figsize=(15,15))
  fig.subplots_adjust(hspace=1, wspace=0.4)
  for i, label in enumerate(labels):
    wfigure = files[label]
    fig.add_subplot(rows, cols, i+1)
    plt.title(label.capitalize())
    data_sample, sample_rate = librosa.load(wfigure)
    librosa.display.waveplot(data_sample, sr= sample_rate)

    ## TODO: return image figure

# %% [markdown]
# ## **3 TECNICAS DE _DATA AUGMENTATION_ EN SONIDO**

# %%
def white_noise(data):
  '''
  Agrega ruido blanco a una pista de audio
  '''
  # print("data: {}".format(data.shape))
  wn_spectrum = np.random.randn(len(data))
  data_wn = sample_data + 0.005*wn_spectrum
  return data_wn

def shift_audio_sample(data, f_low = -5, f_high = 5, spec = 1):
  '''
  Desplaza una se;al acustica en un rango de frecuencia
  '''
  d_range = int(np.random.uniform(low=f_low, high = f_high)*spec) 
# d_range = np.random.uniform(low=1.5, high=3)
  data_shiftted = np.roll(data, d_range)
  return data_shiftted
  # librosa.display.waveplot(data_shiftted, sr=16000)
  # ipd.Audio(data_shiftted, rate=16000)

def pitch_shift(data, bins_per_octave=12, pitch_pm = 2):
  '''
  Modula el tono y modifica la velocidad de una pista de audio
  '''
  pitch_change =  pitch_pm * 2*(np.random.uniform())   
  data_pitch = librosa.effects.pitch_shift(data.astype('float64'),16000, n_steps=pitch_change, bins_per_octave=bins_per_octave)
  return data_pitch


sample_data = librosa.core.load(random_sample)[0]

# %% [markdown]
# ### **3.1 RUIDO BLANCO**
# TODO
# > - Explicacion ruido blanco
# > - Adjust rate spectrum
# > - Comparison respective the original. How do they change?

# %%
data_wn = white_noise(sample_data)
librosa.display.waveplot(data_wn, sr=16000)
ipd.Audio(data_wn, rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### **3.2 DESPLAZAMIENTO DEL SONIDO**
#
# TODO
# > [shifting](https://stackoverflow.com/questions/57362543/how-to-properly-use-pitch-shift-librosa)

# %%
d_range = int(np.random.uniform(low=-5, high = 5)*500) # Optional
# d_range = np.random.uniform(low=1.5, high=3)
data_shiftted = np.roll(sample_data, d_range)
librosa.display.waveplot(data_shiftted, sr=16000)
ipd.Audio(data_shiftted, rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### **3.3 MODULACION DEL TONO**

# %%
bins_per_octave = 12
pitch_pm = 2
pitch_change =  pitch_pm * 2*(np.random.uniform())   
data_pitch = librosa.effects.pitch_shift(sample_data.astype('float64'),16000, n_steps=pitch_change, bins_per_octave=bins_per_octave)

librosa.display.waveplot(data_pitch, sr=16000)
ipd.Audio(data_pitch, rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## **4. PROCESAMIENTO DE DATOS**

# %% [markdown]
# ### **4.1 EXTRACCION DE CARACTERISTICAS**

# %%
def get_features(df, modifier):
  '''
  Extrae las caracteristicas de un conjunto de pistas de audio a 
  partir de un dataframe usando librosa

  Aguments
  ---------
    df : dataframe
    Dataframe que contiene el path donde se encuentra la pista de audio
    modifier: Function
    Funcion que modifica los datos

  Return
  -------
   data: np.array 
   Caracteristicas extraidas

  '''
  bar_data_range = tqdm(range(len(df)))
  data = pd.DataFrame(columns = ['data'])
  for index in bar_data_range:
    data_features = modifier(df.path[index])
    data.loc[index] = [data_features]

  return data

def get_features_single_file(pathfile):
  '''
  Extrae las caracteristicas  de una unica pista de audio usando MFCC 
  a traves de librosa.
  
  Aguments
  ---------
    pathfile: str 
      Path del archivo del que se extraeran las caracteristicas

  Return
  -------
    data_features

  '''
  X, sample_rate = librosa.load(pathfile, res_type='kaiser_fast')
  mfcc = librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40)
  data_features = np.mean(mfcc.T, axis = 0)

  return data_features



def get_features_white_noise(pathfile):
  '''
  Extrae las caracteristicas  de una unica pista de audio usando MFCC 
  a traves de librosa habiendoles aplicado ruido blanco.
  
  Aguments
  ---------
    pathfile: str 
      Path del archivo del que se extraeran las caracteristicas

  Return
  -------
    data_features

  '''
  X, sample_rate = librosa.load(pathfile, res_type='kaiser_fast')
  X = librosa.core.load(random_sample)[0]

  x_data_wn = white_noise(X)
  mfcc = librosa.feature.mfcc(y=x_data_wn, sr=sample_rate, n_mfcc=40)
  data_features = np.mean(mfcc.T, axis = 0)

  return data_features


def get_features_shiftted(pathfile):
  '''
  Extrae las caracteristicas  de una unica pista de audio usando MFCC 
  a traves de librosa habiendo desplazado las frecuencias perviamente.
  
  Aguments
  ---------
    pathfile: str 
      Path del archivo del que se extraeran las caracteristicas

  Return
  -------
    data_features

   '''
  X, sample_rate = librosa.load(pathfile, res_type='kaiser_fast')
  X = librosa.core.load(pathfile)[0]

  x_data_wn = shift_audio_sample(X)
  mfcc = librosa.feature.mfcc(y=x_data_wn, sr=sample_rate, n_mfcc=40)
  data_features = np.mean(mfcc.T, axis = 0)

  return data_features


def get_features_pitch(pathfile):
  '''
  Aplica modulacion del tono en cada muestra y despues extrae las caracteristicas 
  usando el algoritmo MFCC
  
  Aguments
  ---------
    pathfile: str 
      Path del archivo del que se extraeran las caracteristicas

  Return
  -------
    data_features

  '''
  X, sample_rate = librosa.load(pathfile, res_type='kaiser_fast')
  X = librosa.core.load(pathfile)[0]

  x_data_wn = pitch_shift(X)
  mfcc = librosa.feature.mfcc(y=x_data_wn, sr=sample_rate, n_mfcc=40)
  data_features = np.mean(mfcc.T, axis = 0)


  return data_features

# %% [markdown]
# ### 4.1.1 EXTRACCION DE CARACTERISTICAS ESTANDAR

# %%
features_standard = get_features(EnglishSpeech_df, get_features_single_file)
# Out:
# 100%|██████████| 1440/1440 [17:49<00:00,  1.35it/s]

# %%
# Cada valor es una caracteristica
features_standard_df = pd.DataFrame(features_standard['data'].values.tolist())
# Concateno las columnas genero y emocion para poder dividirlo mas tarde
features_std = pd.concat((features_standard_df, EnglishSpeech_df['gender'], EnglishSpeech_df['emotion']), axis = 1) 
# Elimino filas vacias
features_std = features_std.fillna(0)

# %%
random_aux = shuffle(features_std)
random_aux.head()
# Out:
#                0          1          2  ...        39  gender  emotion
# 149  -530.057434  59.480740  -9.900352  ...  2.138683    male     fear
# 1144 -710.096069  40.656712 -13.243646  ... -0.062299  female  neutral
# 947  -628.635376  54.999306  -4.658513  ...  1.731531  female  disgust
# 468  -630.861084  51.284817   7.663978  ...  4.137619  female  disgust
# 636  -579.506104  50.247738   3.570510  ...  1.808671    male      sad
#
# [5 rows x 42 columns]

# %% [markdown]
# ### **4.2. TRATAMIENTO DE DATOS PARA EL ENTRENAMIENTO**

# %%
def split_training_test(df, n_splits_=1, test_size_=0.33, train_size_=None):
  '''
  Divide el dataset en entrenamieto y test utilizando StratifiedShuffleSplit
  Aguments
  ---------
  Return
  -------
  '''
  X = df.drop(['gender', 'emotion'], axis=1)
  Y = df.emotion
  test_train_stratified = StratifiedShuffleSplit(n_splits = n_splits_, test_size = test_size_, random_state=12)
  for train_index, test_index in test_train_stratified.split(X, Y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    Y_train, Y_test = Y.iloc[train_index], Y.iloc[test_index]

  return X_train, X_test, Y_train, Y_test


def data_normalization(val_train, val_test):
  '''
  Normaliza los datos mejorando la precision y la velocidad del proceso de entrenamiento
  Aguments
  ---------
  Return
  -------
  '''
  mean = np.mean(val_train, axis=0)
  std = np.std(val_train, axis=0)

  X_train = (val_train - mean)/std
  X_test = (val_test - mean)/std

  return X_train, X_test


def data_to_categorical(x_train_norm, y_train, x_test_norm, y_test):
  '''
  Categoriza los datos y los formatea para su uso con keras. Asume que x_train y x_test estan normalizados.
  Aguments
  ---------
  Return
  -------
  '''
  # Preparamos los datos para la categorizacion
  x_train_norm = np.array(x_train_norm)
  y_train = np.array(y_train)
  x_test_norm = np.array(x_test_norm)
  y_test = np.array(y_test)

  # One hot encode 
  label_encoder = LabelEncoder()
  y_train = np_utils.to_categorical(label_encoder.fit_transform(y_train))
  y_test = np_utils.to_categorical(label_encoder.fit_transform(y_test))


  return x_train_norm, y_train, x_test_norm, y_test, label_encoder


def dataset_splitted_gender(dataframe, gender):
  '''
  Devuelve el dataset divido en entrenamiento y test segun el genero

  '''
  if gender == 'female':
    female_features_df = dataframe[(dataframe['gender'] == 'female')]
    X_train, X_test, Y_train, Y_test = data_process(female_features_df)

  elif gender == 'male':
    male_features_df = dataframe[(dataframe['gender'] == 'male')]
    X_train, X_test, Y_train, Y_test = data_process(male_features_df)

  elif gender == '':
    X_train, X_test, Y_train, Y_test = data_process(dataframe)

  return X_train, X_test, Y_train, Y_test




def data_process(features_df):
  '''
  Devuelve el conjunto de datos divido en entrenamiento test procesado correctamente

  '''
  # Division entre entrenamiento y test
  _X_train, _X_test, _Y_train, _Y_test =split_training_test(features_df) 

  # 2. Normaliza los datos
  x_train_norm, x_test_norm = data_normalization(_X_train, _X_test)
  # print(x_train_female_norm.shape)

  # 3. Categorización
  _X_train, Y_train, _X_test, Y_test, labels = data_to_categorical(x_train_norm, _Y_train, x_test_norm, _Y_test)
  # print(labels_female.classes_)

  # 4. Cambio de Dimensión
  X_train = np.expand_dims(_X_train, axis=2)
  X_test = np.expand_dims(_X_test, axis=2)

  return X_train, X_test, Y_train, Y_test

# %% [markdown]
# ### **4.3 DEFINICION DEL MODELO**
# Usamos el modelo que mejor resultado nos ha dado hasta ahora

# %%
def model_cnn(x_train, n_classes):
  model = Sequential()

  model.add(Conv1D(128, 5,padding='same',
                  input_shape=(x_train.shape[1],1),
                   kernel_regularizer=tf.keras.regularizers.l2(0.01)))
  model.add(Activation('relu'))
  model.add(Dropout(0.5))
  model.add(MaxPooling1D(pool_size=(8)))
  model.add(Conv1D(128, 5,padding='same',kernel_regularizer=tf.keras.regularizers.l2(0.01)))
  model.add(Activation('relu'))
  model.add(Dropout(0.25))
  model.add(Flatten())
  # Numero de clases
  model.add(Dense(n_classes))
  model.add(Activation('softmax'))

  return model

def plot_loss_acc(history):
  # Mostramos la grafica loss 
  fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
  ax1.plot(history.history['loss'])
  ax1.plot(history.history['val_loss'])
  ax1.set_title('Loss')
  ax1.set(xlabel='epoch', ylabel='loss')
  ax1.legend(['train', 'test'], loc='upper right')

  # Mostramos la grafica accuracy
  ax2.plot(history.history['accuracy'])
  ax2.plot(history.history['val_accuracy'])
  ax2.set_title('Validation')
  ax2.set(xlabel='epoch', ylabel='acc')

  ax2.legend(['train', 'test'], loc='lower right')

# %% [markdown]
# ## **5. APLICACION DE TECNICAS DE _DATA AUGMENTATION_**

# %% [markdown]
# ### **5.1 EXPERIMENTO CON RUIDO BLANCO**

# %% [markdown]
# #### **5.1.1 EXTRACCION DE CARACTERISTICAS CON RUIDO BLANCO**

# %%
features_wn = get_features(EnglishSpeech_df, get_features_white_noise)
# Out:
# 100%|██████████| 1440/1440 [07:16<00:00,  3.30it/s]

# %%
f_df = pd.DataFrame(features_wn['data'].values.tolist())
# Combino los dos datasets: El original y el modificado
features_wn_df = pd.concat([f_df, EnglishSpeech_df['gender'], EnglishSpeech_df['emotion']], axis = 1)
features_complete_df = pd.concat([features_std, features_wn_df], ignore_index=True)
features_complete_df = features_complete_df.fillna(0)
shuffle(features_complete_df.head())
# Out:
#             0          1         2  ...        39  gender  emotion
# 3 -729.980164  66.515892 -0.941985  ... -3.363193    male     calm
# 2 -695.557861  59.240154 -5.372777  ... -2.812932    male  neutral
# 0 -687.513367  59.441540 -0.703714  ... -3.909605    male  neutral
# 4 -701.648193  73.041389 -3.148731  ... -3.923707    male     calm
# 1 -737.635132  75.560745 -0.719248  ... -4.003767    male     calm
#
# [5 rows x 42 columns]

# %% [markdown]
# #### **5.1.2 DIVISION DEL DATAFRAME**

# %%
# male_features_df = features_complete_df[(features_complete_df['gender'] == 'male')]
# female_features_df = features_complete_df[(features_complete_df['gender'] == 'female')]
X_train_female, X_test_female, female_Y_train, female_Y_test = dataset_splitted_gender(features_complete_df, '')

# %% [markdown]
# #### **5.1.3 ENTRENAMIENTO DEL MODELO**

# %%
model = model_cnn(X_train_female, female_Y_test.shape[1])
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_14 (Conv1D)           (None, 40, 128)           768
# _________________________________________________________________
# activation_21 (Activation)   (None, 40, 128)           0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 40, 128)           0
# _________________________________________________________________
# max_pooling1d_7 (MaxPooling1 (None, 5, 128)            0
# _________________________________________________________________
# conv1d_15 (Conv1D)           (None, 5, 128)            82048
# _________________________________________________________________
# activation_22 (Activation)   (None, 5, 128)            0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 5, 128)            0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 640)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 8)                 5128
# _________________________________________________________________
# activation_23 (Activation)   (None, 8)                 0
# =================================================================
# Total params: 87,944
# Trainable params: 87,944
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = keras.optimizers.RMSprop(lr=0.00005, rho=0.9, epsilon=None, decay=0.0)

model.compile(loss='categorical_crossentropy', 
              optimizer = opt, 
              metrics=['accuracy'])


# Callbacks para tratar el overfitting
rlrp = ReduceLROnPlateau(monitor='val_loss', factor=0.9, patience=20, min_lr=0.000001
100
# 181/181 [==============================] - 1s 8ms/step - loss: 1.5711 - accuracy: 0.4868 - val_loss: 1.7358 - val_accuracy: 0.4839
# Epoch 90/100
# 181/181 [==============================] - 1s 8ms/step - loss: 1.5649 - accuracy: 0.5081 - val_loss: 1.7271 - val_accuracy: 0.4902
# Epoch 91/100
# 181/181 [==============================] - 1s 8ms/step - loss: 1.5651 - accuracy: 0.4974 - val_loss: 1.7283 - val_accuracy: 0.4818
# Epoch 92/100
# 181/181 [==============================] - 1s 8ms/step - loss: 1.5463 - accuracy: 0.5117 - val_loss: 1.7130 - val_accuracy: 0.5014
# Epoch 93/100
# 181/181 [==============================] - 1s 8ms/step - loss: 1.5531 - accuracy: 0.4946 - val_loss: 1.7264 - val_accuracy: 0.4839
# Epoch 94/100
# 181/181 [==============================] - 1s 8ms/step - loss: 1.5658 - accuracy: 0.4844 - val_loss: 1.7066 - val_accuracy: 0.5084
# Epoch 95/100
# 181/181 [==============================] - 1s 8ms/step - loss: 1.5477 - accuracy: 0.5060 - val_loss: 1.7079 - val_accuracy: 0.4986
# Epoch 96/100
# 181/181 [==============================] - 1s 8ms/step - loss: 1.5433 - accuracy: 0.5070 - val_loss: 1.7258 - val_accuracy: 0.4853
# Epoch 97/100
# 181/181 [==============================] - 1s 8ms/step - loss: 1.5287 - accuracy: 0.5235 - val_loss: 1.7089 - val_accuracy: 0.5042
# Epoch 98/100
# 181/181 [==============================] - 1s 8ms/step - loss: 1.5270 - accuracy: 0.5213 - val_loss: 1.7034 - val_accuracy: 0.5063
# Epoch 99/100
# 181/181 [==============================] - 1s 8ms/step - loss: 1.5445 - accuracy: 0.4989 - val_loss: 1.7064 - val_accuracy: 0.4930
# Epoch 100/100
# 181/181 [==============================] - 1s 8ms/step - loss: 1.5400 - accuracy: 0.5124 - val_loss: 1.6912 - val_accuracy: 0.5098

# %% [markdown]
# #### **5.1.4 EVALUACION**

# %%
plot_loss_acc(history)

# %%
# Evaluamos contra test
score = model.evaluate(X_test_female, female_Y_test, batch_size=128)
print("Loss: {} \nAccuracy: {}%".format(score[0], score[1]*100))
# Out:
# 12/12 [==============================] - 0s 6ms/step - loss: 1.6912 - accuracy: 0.5098
# Loss: 1.6912174224853516
# Accuracy: 50.98176598548889%

# %% [markdown]
# ### **5.2 EXPERIMENTO CON DESPLAZAMIENTO DEL SONIDO**

# %%
# Extraigo las caracteristicas por genero
features_shiftted = get_features(EnglishSpeech_df, get_features_shiftted)

# Extraccion de caracteristicas
f_df = pd.DataFrame(features_shiftted['data'].values.tolist())
## Combino los dos datasets: El original y el modificado
features_shiftted_df = pd.concat([f_df, EnglishSpeech_df['gender'], EnglishSpeech_df['emotion']], axis = 1)
features_complete_df = pd.concat([features_std, features_shiftted_df], ignore_index=True)
features_complete_df = features_complete_df.fillna(0)

# Division del dataset en entrenamiento test
X_train_female, X_test_female, female_Y_train, female_Y_test = dataset_splitted_gender(features_complete_df, '')

# Entrenamiento del modelo
model = model_cnn(X_train_female, female_Y_test.shape[1])
model.summary()
opt = keras.optimizers.RMSprop(lr=0.00005, rho=0.9, epsilon=None, decay=0.0)

model.compile(loss='categorical_crossentropy', 
              optimizer = opt, 
              metrics=['accuracy'])

rlrp = ReduceLROnPlateau(monitor='val_loss', factor=0.9, patience=20, min_lr=0.000001)

history = model.fit(X_train_female, female_Y_train, 
                        batch_size=16, 
                        epochs=100, 
                        validation_data=(X_test_female, female_Y_test),
                        callbacks=[rlrp])


# Evaluacion
plot_loss_acc(history)
# Evaluamos contra test
score = model.evaluate(X_test_female, female_Y_test, batch_size=128)
print("Loss: {} \nAccuracy: {}%".format(score[0], score[1]*100))
# Out:
# 100%|██████████| 1440/1440 [06:57<00:00,  3.45it/s]
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_8 (Conv1D)            (None, 40, 128)           768
# _________________________________________________________________
# activation_12 (Activation)   (None, 40, 128)           0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 40, 128)           0
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 5, 128)            0
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 5, 128)            82048
# _________________________________________________________________
# activation_13 (Activation)   (None, 5, 128)            0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 5, 128)            0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 640)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 8)                
100
# 121/121 [==============================] - 1s 8ms/step - loss: 1.6961 - accuracy: 0.4605 - val_loss: 1.8325 - val_accuracy: 0.4574
# Epoch 90/100
# 121/121 [==============================] - 1s 9ms/step - loss: 1.6634 - accuracy: 0.4719 - val_loss: 1.8440 - val_accuracy: 0.4364
# Epoch 91/100
# 121/121 [==============================] - 1s 8ms/step - loss: 1.6965 - accuracy: 0.4730 - val_loss: 1.8410 - val_accuracy: 0.4332
# Epoch 92/100
# 121/121 [==============================] - 1s 8ms/step - loss: 1.6640 - accuracy: 0.4753 - val_loss: 1.8250 - val_accuracy: 0.4532
# Epoch 93/100
# 121/121 [==============================] - 1s 8ms/step - loss: 1.6419 - accuracy: 0.4863 - val_loss: 1.8249 - val_accuracy: 0.4501
# Epoch 94/100
# 121/121 [==============================] - 1s 8ms/step - loss: 1.6928 - accuracy: 0.4527 - val_loss: 1.8272 - val_accuracy: 0.4416
# Epoch 95/100
# 121/121 [==============================] - 1s 8ms/step - loss: 1.6555 - accuracy: 0.4666 - val_loss: 1.8200 - val_accuracy: 0.4585
# Epoch 96/100
# 121/121 [==============================] - 1s 8ms/step - loss: 1.6823 - accuracy: 0.4642 - val_loss: 1.8199 - val_accuracy: 0.4364
# Epoch 97/100
# 121/121 [==============================] - 1s 8ms/step - loss: 1.6486 - accuracy: 0.4659 - val_loss: 1.8256 - val_accuracy: 0.4374
# Epoch 98/100
# 121/121 [==============================] - 1s 8ms/step - loss: 1.6417 - accuracy: 0.5088 - val_loss: 1.8240 - val_accuracy: 0.4479
# Epoch 99/100
# 121/121 [==============================] - 1s 9ms/step - loss: 1.6238 - accuracy: 0.4626 - val_loss: 1.8081 - val_accuracy: 0.4543
# Epoch 100/100
# 121/121 [==============================] - 1s 8ms/step - loss: 1.6234 - accuracy: 0.4811 - val_loss: 1.8074 - val_accuracy: 0.4585
# 8/8 [==============================] - 0s 7ms/step - loss: 1.8074 - accuracy: 0.4585
# Loss: 1.8074344396591187
# Accuracy: 45.84647715091705%

# %% [markdown]
# ### **5.2 EXPERIMENTO CON MODULACION DEL TONO**

# %%
# Extraigo las caracteristicas por genero
features_pitch = get_features(EnglishSpeech_df, get_features_pitch)

# Extraccion de caracteristicas
f_df = pd.DataFrame(features_pitch['data'].values.tolist())
# Combino los dos datasets: El original y el modificado
features_pitch_df = pd.concat([f_df, EnglishSpeech_df['gender'], EnglishSpeech_df['emotion']], axis = 1)
features_complete_df = pd.concat([features_std, features_pitch_df], ignore_index=True)
features_complete_df = features_complete_df.fillna(0)

# Division del dataset en entrenamiento test
X_train_female, X_test_female, female_Y_train, female_Y_test = dataset_splitted_gender(features_complete_df, 'female')

# Entrenamiento del modelo
model = model_cnn(X_train_female, female_Y_test.shape[1])
model.summary()
# opt = keras.optimizers.RMSprop(lr=0.00005, rho=0.9, epsilon=None, decay=0.0)

model.compile(loss='categorical_crossentropy', 
              optimizer = opt, 
              metrics=['accuracy'])

rlrp = ReduceLROnPlateau(monitor='val_loss', factor=0.9, patience=20, min_lr=0.000001)

history = model.fit(X_train_female, female_Y_train, 
                        batch_size=16, 
                        epochs=100, 
                        validation_data=(X_test_female, female_Y_test),
                        callbacks=[rlrp])


# Evaluacion
plot_loss_acc(history)
# Evaluamos contra test
score = model.evaluate(X_test_female, female_Y_test, batch_size=128)
print("Loss: {} \nAccuracy: {}%".format(score[0], score[1]*100))
# Out:
# 100%|██████████| 1440/1440 [10:16<00:00,  2.34it/s]
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_10 (Conv1D)           (None, 40, 128)           768
# _________________________________________________________________
# activation_15 (Activation)   (None, 40, 128)           0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 40, 128)           0
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 5, 128)            0
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, 5, 128)            82048
# _________________________________________________________________
# activation_16 (Activation)   (None, 5, 128)            0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 5, 128)            0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 640)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 8)                 5128
# _________________________________________________________________
# activation_17 (Activation)   (None, 8)                 0
# =================================================================
# Total params: 87,944
# Trainable params: 87,944
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
#
100
# 61/61 [==============================] - 1s 9ms/step - loss: 1.8293 - accuracy: 0.4471 - val_loss: 1.9680 - val_accuracy: 0.4370
# Epoch 90/100
# 61/61 [==============================] - 1s 9ms/step - loss: 1.7871 - accuracy: 0.4721 - val_loss: 1.9693 - val_accuracy: 0.4433
# Epoch 91/100
# 61/61 [==============================] - 1s 9ms/step - loss: 1.7853 - accuracy: 0.4615 - val_loss: 1.9630 - val_accuracy: 0.4328
# Epoch 92/100
# 61/61 [==============================] - 1s 9ms/step - loss: 1.8100 - accuracy: 0.4720 - val_loss: 1.9564 - val_accuracy: 0.4349
# Epoch 93/100
# 61/61 [==============================] - 1s 9ms/step - loss: 1.7667 - accuracy: 0.4543 - val_loss: 1.9661 - val_accuracy: 0.4265
# Epoch 94/100
# 61/61 [==============================] - 1s 9ms/step - loss: 1.7465 - accuracy: 0.5180 - val_loss: 1.9515 - val_accuracy: 0.4349
# Epoch 95/100
# 61/61 [==============================] - 1s 9ms/step - loss: 1.7652 - accuracy: 0.4736 - val_loss: 1.9502 - val_accuracy: 0.4349
# Epoch 96/100
# 61/61 [==============================] - 1s 9ms/step - loss: 1.7702 - accuracy: 0.4771 - val_loss: 1.9546 - val_accuracy: 0.4118
# Epoch 97/100
# 61/61 [==============================] - 1s 9ms/step - loss: 1.7527 - accuracy: 0.4977 - val_loss: 1.9320 - val_accuracy: 0.4517
# Epoch 98/100
# 61/61 [==============================] - 1s 9ms/step - loss: 1.7723 - accuracy: 0.4773 - val_loss: 1.9379 - val_accuracy: 0.4181
# Epoch 99/100
# 61/61 [==============================] - 1s 9ms/step - loss: 1.7670 - accuracy: 0.4657 - val_loss: 1.9246 - val_accuracy: 0.4538
# Epoch 100/100
# 61/61 [==============================] - 1s 9ms/step - loss: 1.7694 - accuracy: 0.4635 - val_loss: 1.9242 - val_accuracy: 0.4412
# 4/4 [==============================] - 0s 7ms/step - loss: 1.9242 - accuracy: 0.4412
# Loss: 1.9241670370101929
# Accuracy: 44.11764740943909%

# %% [markdown]
# ### **5.4 COMBINACION DE TECNICAS: _PITCH TUNNING & SHIFTTING_**

# %%
# Extraigo las caracteristicas por genero
if 'features_shiftted' not in globals() or features_shiftted.empty:
  features_shiftted = get_features(EnglishSpeech_df, get_features_shiftted)
if 'features_pitch' not in globals() or features_pitch.empty:
  features_pitch = get_features(EnglishSpeech_df, get_features_pitch)

# Extraccion de caracteristicas
f_df_shift = pd.DataFrame(features_shiftted['data'].values.tolist())
f_df_pitch = pd.DataFrame(features_pitch['data'].values.tolist())
## Combino los dos datasets:
features_shiftted_df = pd.concat([f_df_shift, EnglishSpeech_df['gender'], EnglishSpeech_df['emotion']], axis = 1)
features_pitch_df = pd.concat([f_df_pitch, EnglishSpeech_df['gender'], EnglishSpeech_df['emotion']], axis = 1)
comb_datasets = [features_std, features_shiftted_df, features_pitch_df]
features_complete_df = pd.concat(comb_datasets, ignore_index=True)
features_complete_df.shape
# Out:
# (4320, 42)

# %%
# # Division del dataset en entrenamiento test
X_train_female, X_test_female, female_Y_train, female_Y_test = dataset_splitted_gender(features_complete_df, '')
print ("Entrenado con {} muestras. \nTesteado con {} muestras".format(X_train_female.shape[0], X_test_female.shape[0]) )
# Entrenamiento del modelo
model = model_cnn(X_train_female, female_Y_test.shape[1])
model.summary()
opt = keras.optimizers.RMSprop(lr=0.00005, rho=0.9, epsilon=None, decay=0.0)

model.compile(loss='categorical_crossentropy', 
              optimizer = opt, 
              metrics=['accuracy'])

rlrp = ReduceLROnPlateau(monitor='val_loss', factor=0.9, patience=20, min_lr=0.000001)
history = model.fit(X_train_female, female_Y_train, 
                        batch_size=16, 
                        epochs=100, 
                        validation_data=(X_test_female, female_Y_test), 
                        callbacks=[rlrp])


# Evaluacion
plot_loss_acc(history)
# Evaluamos contra test
score = model.evaluate(X_test_female, female_Y_test, batch_size=128)
print("Loss: {} \nAccuracy: {}%".format(score[0], score[1]*100))
# Out:
# Entrenado con 2894 muestras.
# Testeado con 1426 muestras
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_2 (Conv1D)            (None,
100
# 181/181 [==============================] - 1s 7ms/step - loss: 1.6202 - accuracy: 0.4726 - val_loss: 1.7812 - val_accuracy: 0.4481
# Epoch 87/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1.6262 - accuracy: 0.4783 - val_loss: 1.7813 - val_accuracy: 0.4397
# Epoch 88/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1.6332 - accuracy: 0.4622 - val_loss: 1.7742 - val_accuracy: 0.4579
# Epoch 89/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1.6196 - accuracy: 0.4657 - val_loss: 1.7788 - val_accuracy: 0.4411
# Epoch 90/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1.6367 - accuracy: 0.4682 - val_loss: 1.7790 - val_accuracy: 0.4495
# Epoch 91/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1.6513 - accuracy: 0.4503 - val_loss: 1.7827 - val_accuracy: 0.4383
# Epoch 92/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1.6508 - accuracy: 0.4670 - val_loss: 1.7647 - val_accuracy: 0.4551
# Epoch 93/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1.5899 - accuracy: 0.4900 - val_loss: 1.7611 - val_accuracy: 0.4593
# Epoch 94/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1.5962 - accuracy: 0.4973 - val_loss: 1.7661 - val_accuracy: 0.4488
# Epoch 95/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1.6066 - accuracy: 0.4765 - val_loss: 1.7567 - val_accuracy: 0.4530
# Epoch 96/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1.6150 - accuracy: 0.4692 - val_loss: 1.7676 - val_accuracy: 0.4481
# Epoch 97/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1.6014 - accuracy: 0.4752 - val_loss: 1.7641 - val_accuracy: 0.4635
# Epoch 98/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1.5939 - accuracy: 0.4920 - val_loss: 1.7552 - val_accuracy: 0.4593
# Epoch 99/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1.6041 - accuracy: 0.4610 - val_loss: 1.7492 - val_accuracy: 0.4748
# Epoch 100/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1.6442 - accuracy: 0.4549 - val_loss: 1.7499 - val_accuracy: 0.4558
# 12/12 [==============================] - 0s 5ms/step - loss: 1.7499 - accuracy: 0.4558
# Loss: 1.7498972415924072
# Accuracy: 45.58204710483551%

# %%
# LPATH_DATA = SpeechEmotionRecognition/data/procesed/
# features_complete_df.to_hdf('features_complete.h5', key='df')
# features_shiftted_df.to_hdf('features_shiftted.h5', key='df')
# features_pitch_df.to_hdf('features_pitch.h5', key='df')
# features_standard_df.to_hdf('features_standard.h5', key='df')

# %% [markdown]
# ### **5.5 COMBINACION DE TECNICAS: _WHITE NOISE & SHIFTTING_**

# %%
# Extraigo las caracteristicas por genero
if 'features_shiftted' not in globals() or features_shiftted.empty:
  features_shiftted = get_features(EnglishSpeech_df, get_features_shiftted)
if 'features_wn' not in globals() or features_wn.empty:
  features_wn = get_features(EnglishSpeech_df, get_features_white_noise)

# Extraccion de caracteristicas
f_df_shift = pd.DataFrame(features_shiftted['data'].values.tolist())
f_df_wn = pd.DataFrame(features_wn['data'].values.tolist())
## Combino los dos datasets:
features_shiftted_df = pd.concat([f_df_shift, EnglishSpeech_df['gender'], EnglishSpeech_df['emotion']], axis = 1)
features_wn_df = pd.concat([f_df_wn, EnglishSpeech_df['gender'], EnglishSpeech_df['emotion']], axis = 1)
comb_datasets = [features_std, features_shiftted_df, features_wn_df]
features_complete_df = pd.concat(comb_datasets, ignore_index=True)
features_complete_df.shape
# Out:
# 100%|██████████| 1440/1440 [06:46<00:00,  3.54it/s]
# (4320, 42)

# %%
# # Division del dataset en entrenamiento test
X_train_female, X_test_female, female_Y_train, female_Y_test = dataset_splitted_gender(features_complete_df, '')
print ("Entrenado con {} muestras. \nTesteado con {} muestras".format(X_train_female.shape[0], X_test_female.shape[0]) )
# Entrenamiento del modelo
model = model_cnn(X_train_female, female_Y_test.shape[1])
model.summary()
opt = keras.optimizers.RMSprop(lr=0.00005, rho=0.9, epsilon=None, decay=0.0)

model.compile(loss='categorical_crossentropy', 
              optimizer = opt, 
              metrics=['accuracy'])

rlrp = ReduceLROnPlateau(monitor='val_loss', factor=0.9, patience=20, min_lr=0.000001)

history = model.fit(X_train_female, female_Y_train, 
                        batch_size=16, 
                        epochs=100, 
                        validation_data=(X_test_female, female_Y_test), 
                        callbacks=[rlrp])


# Evaluacion
plot_loss_acc(history)
# Evaluamos contra test
score = model.evaluate(X_test_female, female_Y_test, batch_size=128)
print("Loss: {} \nAccuracy: {}%".format(score[0], score[1]*100))
# Out:
# Entrenado con 2894 muestras.
# Testeado con 1426 muestras
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_4 (Conv1D)            (None, 40, 128)           768
# _________________________________________________________________
# activation_6 (Activation)    (None, 40, 128)           0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 40, 128)           0
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 5, 128)            0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 5, 128)            82048
# _________________________________________________________________
# activation_7 (Activation)    (None, 5, 128)            0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 5, 128)            0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 640)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 5128
# _________________________________________________________________
# activation_8 (Activation)    (None, 8)                 0
# =================================================================
# Total params: 87,944
# Trainable params: 87,944
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 181/181 [==============================] - 2s 8ms/step - loss: 3.3505 - accuracy: 0.1264 - val_loss: 3.2096 - val_accuracy: 0.1795
# Epoch 2/100
# 181/181 [==============================] - 1s 7ms/step - loss: 3.1501 - accuracy: 0.1970 - val_loss: 3.0853 - val_accuracy: 0.1767
# Epoch 3/100
# 181/181 [==============================] - 1s 7ms/step - loss: 3.0319 - accuracy: 0.2076 - val_loss: 2.9794 - val_accuracy: 0.2034
# Epoch 4/100
# 181/181 [==============================] - 1s 7ms/step - loss: 2.9282 - accuracy: 0.2119 - val_loss: 2.8873 - val_accuracy: 0.1978
# Epoch 5/100
# 181/181 [==============================] - 1s 7ms/step - loss: 2.8313 - accuracy: 0.2178 - val_loss: 2.8090 - val_accuracy: 0.2167
# Epoch 6/100
# 181/181 [==============================] - 1s 7ms/step - loss: 2.7520 - accuracy: 0.2349 - val_loss: 2.7404 - val_accuracy: 0.2314
# Epoch 7/100
# 181/181 [==============================] - 1s 7ms/step - loss: 2.6878 - accuracy: 0.2261 - val_loss: 2.6807 - val_accuracy: 0.2370
# Epoch 8/100
# 181/181 [==============================] - 1s 7ms/step - loss: 2.6291 - accuracy: 0.2388 - val_loss: 2.6341 - val_accuracy: 0.2391
# Epoch 9/100
# 181/181 [==============================] - 1s 7ms/step - loss: 2.5586 - accuracy: 0.2552 - val_loss: 2.5885 - val_accuracy: 0.2433
# Epoch 10/100
# 181/181 [==============================] - 1s 7ms/step - loss: 2.5325 - accuracy: 0.2435 - val_loss: 2.5494 - val_accuracy: 0.2539
# Epoch 11/100
# 181/181 [==============================] - 1s 7ms/step - loss: 2.4947 - accuracy: 0.2374 - val_loss: 2.5076 - val_accuracy: 0.2525
# Epoch 12/100
# 181/181 [==============================] - 1s 7ms/step - loss: 2.4300 - accuracy: 0.2620 - val_loss: 2.4766 - val_accuracy: 0.2644
# Epoch 13/100
# 181/181 [==============================] - 1s 7ms/step - loss: 2.4198 - accuracy: 0.2574 - val_loss: 2.4450 - val_accuracy: 0.2616
# Epoch 14/100
# 181/181 [==============================] - 1s 7ms/step - loss: 2.3471 - accuracy: 0.2783 - val_loss: 2.4175 - val_accuracy: 0.2700
# Epoch 15/100
# 181/181 [==============================] - 1s 7ms/step - loss: 2.3602 - accuracy: 0.2612 - val_loss: 2.3899 - val_accuracy: 0.2651
# Epoch 16/100
# 181/181 [==============================] - 1s 7ms/step - loss: 2.3233 - accuracy: 0.2675 - val_loss: 2.3667 - val_accuracy: 0.2651
# Epoch 17/100
# 181/181 [==============================] - 1s 7ms/step - loss: 2.3087 - accuracy: 0.2576 - val_loss: 2.3411 - val_accuracy: 0.2735
# Epoch 18/100
# 181/181 [==============================] - 1s 7ms/step - loss: 2.2736 - accuracy: 0.2719 - val_loss: 2.3188 - val_accuracy: 0.2756
# Epoch 19/100
# 181/181 [==============================] - 1s 7ms/step - loss: 2.2371 - accuracy: 0.2851 - val_loss: 2.3009 - val_accuracy: 0.2679
# Epoch 20/100
# 181/181 [==============================] - 1s 7ms/step - loss: 2.2345 - accuracy: 0.2787 - val_loss: 2.2857 - val_accuracy: 0.2763
# Epoch 21/100
# 181/181 [==============================] - 1s 7ms/step - loss: 2
100
# 181/181 [==============================] - 1s 7ms/step - loss: 1.8240 - accuracy: 0.3430 - val_loss: 1.9358 - val_accuracy: 0.3282
# Epoch 83/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1.8226 - accuracy: 0.3429 - val_loss: 1.9393 - val_accuracy: 0.3191
# Epoch 84/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1.8172 - accuracy: 0.3476 - val_loss: 1.9363 - val_accuracy: 0.3079
# Epoch 85/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1.8161 - accuracy: 0.3467 - val_loss: 1.9301 - val_accuracy: 0.3198
# Epoch 86/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1.7986 - accuracy: 0.3467 - val_loss: 1.9323 - val_accuracy: 0.3331
# Epoch 87/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1.8147 - accuracy: 0.3471 - val_loss: 1.9370 - val_accuracy: 0.3156
# Epoch 88/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1.7928 - accuracy: 0.3407 - val_loss: 1.9231 - val_accuracy: 0.3317
# Epoch 89/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1.8080 - accuracy: 0.3485 - val_loss: 1.9229 - val_accuracy: 0.3366
# Epoch 90/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1.7912 - accuracy: 0.3668 - val_loss: 1.9258 - val_accuracy: 0.3345
# Epoch 91/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1.7875 - accuracy: 0.3380 - val_loss: 1.9202 - val_accuracy: 0.3345
# Epoch 92/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1.8029 - accuracy: 0.3555 - val_loss: 1.9209 - val_accuracy: 0.3373
# Epoch 93/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1.7898 - accuracy: 0.3533 - val_loss: 1.9209 - val_accuracy: 0.3156
# Epoch 94/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1.7913 - accuracy: 0.3531 - val_loss: 1.9147 - val_accuracy: 0.3324
# Epoch 95/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1.8011 - accuracy: 0.3486 - val_loss: 1.9193 - val_accuracy: 0.3352
# Epoch 96/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1.7857 - accuracy: 0.3549 - val_loss: 1.9160 - val_accuracy: 0.3366
# Epoch 97/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1.7809 - accuracy: 0.3535 - val_loss: 1.9231 - val_accuracy: 0.3296
# Epoch 98/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1.7778 - accuracy: 0.3594 - val_loss: 1.9151 - val_accuracy: 0.3205
# Epoch 99/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1.7721 - accuracy: 0.3693 - val_loss: 1.9217 - val_accuracy: 0.3149
# Epoch 100/100
# 181/181 [==============================] - 1s 7ms/step - loss: 1.7946 - accuracy: 0.3590 - val_loss: 1.9135 - val_accuracy: 0.3359
# 12/12 [==============================] - 0s 5ms/step - loss: 1.9135 - accuracy: 0.3359
# Loss: 1.9134784936904907
# Accuracy: 33.59046280384064%

# %% [markdown]
# ### **5.5 COMBINACION DE TECNICAS: _WHITE NOISE + SHIFTTING + PITCH TUNNING_**

# %%
# Extraigo las caracteristicas por genero
if 'features_shiftted' not in globals() or features_shiftted.empty:
  features_shiftted = get_features(EnglishSpeech_df, get_features_shiftted)
if 'features_wn' not in globals() or features_wn.empty:
  features_wn = get_features(EnglishSpeech_df, get_features_white_noise)
if 'features_pitch' not in globals() or features_pitch.empty:
  features_pitch = get_features(EnglishSpeech_df, get_features_pitch)

# Extraccion de caracteristicas
f_df_shift = pd.DataFrame(features_shiftted['data'].values.tolist())
f_df_wn = pd.DataFrame(features_wn['data'].values.tolist())
f_df_pitch = pd.DataFrame(features_pitch['data'].values.tolist())
## Combino los dos datasets:
features_shiftted_df = pd.concat([f_df_shift, EnglishSpeech_df['gender'], EnglishSpeech_df['emotion']], axis = 1)
features_wn_df = pd.concat([f_df_wn, EnglishSpeech_df['gender'], EnglishSpeech_df['emotion']], axis = 1)
features_pitch_df = pd.concat([f_df_pitch, EnglishSpeech_df['gender'], EnglishSpeech_df['emotion']], axis = 1)
comb_datasets = [features_std, features_shiftted_df, features_wn_df, features_pitch_df]
features_complete_df = pd.concat(comb_datasets, ignore_index=True)
features_complete_df.shape
# Out:
# (5760, 42)

# %%
# # Division del dataset en entrenamiento test
X_train_female, X_test_female, female_Y_train, female_Y_test = dataset_splitted_gender(features_complete_df, '')
print ("Entrenado con {} muestras. \nTesteado con {} muestras".format(X_train_female.shape[0], X_test_female.shape[0]) )
# Entrenamiento del modelo
model = model_cnn(X_train_female, female_Y_test.shape[1])
model.summary()
opt = keras.optimizers.RMSprop(lr=0.00005, rho=0.9, epsilon=None, decay=0.0)

model.compile(loss='categorical_crossentropy', 
              optimizer = opt, 
              metrics=['accuracy'])

# rlrp = ReduceLROnPlateau(monitor='val_loss', factor=0.9, patience=20, min_lr=0.000001)

history = model.fit(X_train_female, female_Y_train, 
                        batch_size=16, 
                        epochs=100, 
                        validation_data=(X_test_female, female_Y_test), 
                        callbacks=[rlrp])


# Evaluacion
plot_loss_acc(history)
# Evaluamos contra test
score = model.evaluate(X_test_female, female_Y_test, batch_size=128)
print("Loss: {} \nAccuracy: {}%".format(score[0], score[1]*100))
# Out:
# Entrenado con 3859 muestras.
# Testeado con 1901 muestras
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_10 (Conv1D)           (None, 40, 128)           768
# _________________________________________________________________
# activation_15 (Activation)   (None, 40, 128)           0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 40, 128)           0
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 5, 128)            0
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, 5, 128)            82048
# _________________________________________________________________
# activation_16 (Activation)   (None, 5, 128)            0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 5, 128)            0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 640)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 8)                 5128
# _________________________________________________________________
# activation_17 (Activation)   (None, 8)                 0
# =================================================================
# Total params: 87,944
# Trainable params: 87,944
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 242/242 [==============================] - 2s 7ms/step - loss: 3.3142 - accuracy: 0.1424 - val_loss: 3.1724 - val_accuracy: 0.2162
# Epoch 2/100
# 242/242 [==============================] - 2s 7ms/step - loss: 3.1219 - accuracy: 0.1886 - val_loss: 3.0285 - val_accuracy: 0.2236
# Epoch 3/100
# 242/242 [==============================] - 2s 7ms/step - loss: 2.9766 - accuracy: 0.2168 - val_loss: 2.9132 - val_accuracy: 0.2415
# Epoch 4/100
# 242/242 [==============================] - 2s 7ms/step - loss: 2.8625 - accuracy: 0.2157 - val_loss: 2.8169 - val_accuracy: 0.2251
# Epoch 5/100
# 242/242 [==============================] - 2s 7ms/step - loss: 2.7698 - accuracy: 0.2231 - val_loss: 2.7367 - val_accuracy: 0.2514
# Epoch 6/100
# 242/242 [==============================] - 2s 7ms/step - loss: 2.6791 - accuracy: 0.2267 - val_loss: 2.6672 - val_accuracy: 0.2630
# Epoch 7/100
# 242/242 [==============================] - 2s 7ms/step - loss: 2.6183 - accuracy: 0.2324 - val_loss: 2.6045 - val_accuracy: 0.2678
# Epoch 8/100
# 242/242 [==============================] - 2s 7ms/step - loss: 2.5417 - accuracy: 0.2566 - val_loss: 2.5510 - val_accuracy: 0.2604
# Epoch 9/100
# 242/242 [==============================] - 2s 7ms/step - loss: 2.4999 - accuracy: 0.2520 - val_loss: 2.5035 - val_accuracy: 0.2683
# Epoch 10/100
# 242/242 [==============================] - 2s 7ms/step - loss: 2.4314 - accuracy: 0.2787 - val_loss: 2.4616 - val_accuracy: 0.2656
# Epoch 11/100
# 242/242 [==============================] - 2s 7ms/step - loss: 2.3998 - accuracy: 0.2690 - val_loss: 2.4220 - val_accuracy: 0.2614
# Epoch 12/100
# 242/242 [==============================] - 2s 7ms/step - loss: 2.3618 - accuracy: 0.2741 - val_loss: 2.3852 - val_accuracy: 0.2756
# Epoch 13/100
# 242/242 [==============================] - 2s 7ms/step - loss: 2.3139 - accuracy: 0.2788 - val_loss: 2.3561 - val_accuracy: 0.2867
# Epoch 14/100
# 242/242 [==============================] - 2s 7ms/step - loss: 2.2873 - accuracy: 0.2875 - val_loss: 2.3209 - val_accuracy: 0.2835
# Epoch 15/100
# 242/242 [==============================] - 2s 7ms/step - loss: 2.2473 - accuracy: 0.2824 - val_loss: 2.2977 - val_accuracy: 0.2888
# Epoch 16/100
# 242/242 [==============================] - 2s 7ms/step - loss: 2.2169 - accuracy: 0.2795 - val_loss: 2.2741 - val_accuracy: 0.2956
# Epoch 17/100
# 242/242 [==============================] - 2s 7ms/step - loss: 2.2073 - accuracy: 0.2878 - val_loss: 2.2459 - val_accuracy: 0.3046
# Epoch 18/100
# 242/242 [==============================] - 2s 7ms/step - loss: 2
100
# 242/242 [==============================] - 2s 7ms/step - loss: 1.7535 - accuracy: 0.3691 - val_loss: 1.8797 - val_accuracy: 0.3577
# Epoch 80/100
# 242/242 [==============================] - 2s 7ms/step - loss: 1.7403 - accuracy: 0.3812 - val_loss: 1.8779 - val_accuracy: 0.3556
# Epoch 81/100
# 242/242 [==============================] - 2s 7ms/step - loss: 1.7379 - accuracy: 0.3917 - val_loss: 1.8682 - val_accuracy: 0.3640
# Epoch 82/100
# 242/242 [==============================] - 2s 7ms/step - loss: 1.7360 - accuracy: 0.3770 - val_loss: 1.8684 - val_accuracy: 0.3619
# Epoch 83/100
# 242/242 [==============================] - 2s 7ms/step - loss: 1.7544 - accuracy: 0.3873 - val_loss: 1.8636 - val_accuracy: 0.3672
# Epoch 84/100
# 242/242 [==============================] - 2s 7ms/step - loss: 1.7531 - accuracy: 0.3801 - val_loss: 1.8706 - val_accuracy: 0.3661
# Epoch 85/100
# 242/242 [==============================] - 2s 7ms/step - loss: 1.7489 - accuracy: 0.3775 - val_loss: 1.8748 - val_accuracy: 0.3503
# Epoch 86/100
# 242/242 [==============================] - 2s 7ms/step - loss: 1.7313 - accuracy: 0.3917 - val_loss: 1.8672 - val_accuracy: 0.3582
# Epoch 87/100
# 242/242 [==============================] - 2s 7ms/step - loss: 1.7385 - accuracy: 0.3844 - val_loss: 1.8689 - val_accuracy: 0.3561
# Epoch 88/100
# 242/242 [==============================] - 2s 7ms/step - loss: 1.7470 - accuracy: 0.3754 - val_loss: 1.8577 - val_accuracy: 0.3719
# Epoch 89/100
# 242/242 [==============================] - 2s 7ms/step - loss: 1.7459 - accuracy: 0.3824 - val_loss: 1.8684 - val_accuracy: 0.3530
# Epoch 90/100
# 242/242 [==============================] - 2s 7ms/step - loss: 1.7570 - accuracy: 0.3721 - val_loss: 1.8812 - val_accuracy: 0.3425
# Epoch 91/100
# 242/242 [==============================] - 2s 7ms/step - loss: 1.7413 - accuracy: 0.3711 - val_loss: 1.8552 - val_accuracy: 0.3693
# Epoch 92/100
# 242/242 [==============================] - 2s 7ms/step - loss: 1.7426 - accuracy: 0.3689 - val_loss: 1.8688 - val_accuracy: 0.3677
# Epoch 93/100
# 242/242 [==============================] - 2s 7ms/step - loss: 1.7462 - accuracy: 0.3797 - val_loss: 1.8659 - val_accuracy: 0.3546
# Epoch 94/100
# 242/242 [==============================] - 2s 7ms/step - loss: 1.6883 - accuracy: 0.4232 - val_loss: 1.8552 - val_accuracy: 0.3803
# Epoch 95/100
# 242/242 [==============================] - 2s 7ms/step - loss: 1.7301 - accuracy: 0.3805 - val_loss: 1.8712 - val_accuracy: 0.3477
# Epoch 96/100
# 242/242 [==============================] - 2s 7ms/step - loss: 1.7310 - accuracy: 0.3814 - val_loss: 1.8594 - val_accuracy: 0.3598
# Epoch 97/100
# 242/242 [==============================] - 2s 7ms/step - loss: 1.7198 - accuracy: 0.3927 - val_loss: 1.8573 - val_accuracy: 0.3677
# Epoch 98/100
# 242/242 [==============================] - 2s 7ms/step - loss: 1.7422 - accuracy: 0.3815 - val_loss: 1.8510 - val_accuracy: 0.3714
# Epoch 99/100
# 242/242 [==============================] - 2s 7ms/step - loss: 1.7148 - accuracy: 0.3896 - val_loss: 1.8537 - val_accuracy: 0.3519
# Epoch 100/100
# 242/242 [==============================] - 2s 7ms/step - loss: 1.7235 - accuracy: 0.3808 - val_loss: 1.8655 - val_accuracy: 0.3477
# 15/15 [==============================] - 0s 5ms/step - loss: 1.8655 - accuracy: 0.3477
# Loss: 1.8655260801315308
# Accuracy: 34.77117419242859%

# %% [markdown]
# _REFERENCES_
# * [validation static](https://stats.stackexchange.com/questions/255105/why-is-the-validation-accuracy-fluctuating)
# * [validation constant](https://datascience.stackexchange.com/questions/13607/validation-loss-and-accuracy-remain-constant)
# * [leverage overfit](https://www.tensorflow.org/tutorials/keras/overfit_and_underfit)
# *[improve val loss and val acc](https://stackoverflow.com/questions/61520180/how-to-improve-val-loss-and-val-acc)
# * [Loss curves](https://datascience.stackexchange.com/questions/52028/understanding-training-and-test-loss-plots)
# * [CNN and regularization techniques](https://medium.com/intelligentmachines/convolutional-neural-network-and-regularization-techniques-with-tensorflow-and-keras-5a09e6e65dc7)
# * [Tensorflow playground](http://playground.tensorflow.org/#activation=tanh&batchSize=10&dataset=circle&regDataset=reg-plane&learningRate=0.03&regularizationRate=0&noise=0&networkShape=4,2&seed=0.62971&showTestData=false&discretize=false&percTrainData=50&x=true&y=true&xTimesY=false&xSquared=false&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=classification&initZero=false&hideText=false&batchSize_hide=false)
